# %% [markdown]
# # Collective Loan in Marlowe
#
#
# **Executive Summary**
#
# This collective-loan contract lets lenders deposit currency such as `DjedUSD` in exchange for liquidity tokens, and then lets borrowers draw funds from the contract as loans. After the borrowers pay back their borrowings with interest to the collective loan, the lenders then redeem their liquidity tokens for `DjedUSD` that includes profit from the lending. A central administrator manages approvals. The Marlowe contract for this collective loan is scalable to an arbitrarily largenumber of lenders or borrowers, so long as the trusted central administrator is relied upon to disperse role tokens on a just-in-time basis. (Less centralized versions may be feasible, but they would be more rigid in terms of sequence of participation of the lenders and borrowers.) The contract was both simulated and run on the Cardano blockchain: that involved 30 lenders, 70 borrowers, and ~530 transactions.
#
# [A simple one-lender, one-borrower version of this contract](collective-loan.blockly) is available for use in [Marlowe Playground's Blockly/Marlowe format](https://marlowe-playground-staging.plutus.aws.iohkdev.io/#/marlowe).
#
# See also [this video](https://vimeo.com/735889853/10601168e4) that walks through this example in Marlowe Playground and on the Marlowe testnet.
#
#
# **Highlights**
#
# *   Arbitrary scalability for Marlowe contracts where role-tokens are dispersed on a just-in-time basis.
# *   Incremental merkleization for rapid construction of large Marlowe contracts.
# *   Novel merkleization of timeouts to limit contract depth.
#
#
# ***Life cycle of this collective loan:***
#
# 1.  The administrator configures and creates the contract.
# 2.  The administrator deposits the liquidity tokens for the contract.
# 3.  Lenders request to deposit their investment funds.
#     1.  The administrator approves the lender.
#     2.  The administrator sends a role token to the lender.
#     3.  The lender deposits their funds.
#     4.  The lender receives liquidity tokens as a receipt.
# 4.  Borrowers requests loans from the collective loan.
#     1.  The administrator authorizes the loan.
#     2.  The administrator sends a role token to the borrower.
#     3.  The borrower withdraws their funds.
# 5.  Borrowers deposit their loan proceeds.
# 6.  Lenders redeem their liquidity tokens.
# 7.  The administrator closes the contract.
#
#
# ***Caveats and limitations***
#
# -   The contract has a finite life cycle with phases of investment, lending, repayment, and redemption.
# -   The administrator may be an organization or an oracle, manual or automated, but it must be highly secure.
#     -   For example, a contract with 100 lenders and 5000 loans will fit-on chain if it is merkleized: such a contract contains 20,601 small continuations that account for all possible logical paths through the contract.
#     -   However, we have not studied how the arbitrary *interleaving* of lending and payback may affect scalability.
# -   Unlike fully decentralized Marlowe contracts, this collective-loan contract relies upon centralized management of role tokens to bypass the Marlowe's limitations on the number of state variables (which are stored in Plutus `Datum`).
#     -   The use of reference scripts (CIP-33) in the Babbage Era may somewhat alleviate this limitation.
#     -   Role tokens can be pre-distributed *if lenders and borrowers submit transactions in a pre-defined order*: this will decrease centralization and increase security at the expense of making the contract more rigid.

# %% [markdown]
# ## Sequence Diagram
#
# ![UML sequence diagram for collective loan](collective-loan.png)

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# ### Versions

# %% [markdown]
# Make a note of the versions of the Marlowe repository and software.

# %%
marlowe-cli --version
# Out:
# marlowe-cli 0.0.5.0

# %%
cardano-cli --version
# Out:
# cardano-cli 1.35.2 - linux-x86_64 - ghc-8.10
# git rev 0000000000000000000000000000000000000000

# %%
git rev-parse HEAD
# Out:
# f5a0f64d8697dd7a29af91b11530039dc98a1d44

# %% [markdown]
# ### Utility Functions

# %% [markdown]
# The following functions simplify UTxO management.

# %%
function find_role_token() {
  marlowe-cli util select --asset-only $ROLES_POLICY.$2 $1 | sed -e 's/^TxIn "\(.*\)" (TxIx \(.*\))$/\1#\2/'
}

# %%
function find_ada() {
  marlowe-cli util select --lovelace-only $((10 * ADA)) $1 | sed -e 's/^TxIn "\(.*\)" (TxIx \(.*\))$/\1#\2/' | head -n 1
}

# %%
function find_token() {
  marlowe-cli util select --asset-only $2 $1 | sed -e 's/^TxIn "\(.*\)" (TxIx \(.*\))$/\1#\2/' | head -n 1
}

# %%
function find_token_2() {
  marlowe-cli util select --asset-only $2 $1 | sed -e 's/^TxIn "\(.*\)" (TxIx \(.*\))$/\1#\2/' | tail -n +2 | head -n 1
}

# %%
function make_role_txout () {
  echo "$1+$MIN_ADA+1 $ROLES_POLICY.$2"
}

# %%
function make_token_txout() {
  echo "$1+$MIN_ADA+$3 $2"
}

# %% [markdown]
# ### Select the Cardano network

# %%
export CARDANO_TESTNET_MAGIC=1567
export CARDANO_NODE_SOCKET_PATH=node.socket

# %% [markdown]
# ### Current Time

# %% [markdown]
# We'll start the contract at the current time.

# %%
NOW=$(($(date -u +%s) * 1000))
echo $NOW
# Out:
# 1660498029000

# %% [markdown]
# Compute time constants, for convenience when setting time intervals for transactions.

# %%
MINUTE=$((60 * 1000))
HOUR=$((60 * MINUTE))
DAY=$((24 * HOUR))

# %% [markdown]
# There is a minimum Ada requirement associated with a native token.

# %%
ADA=1000000
MIN_ADA=$((2 * ADA))
echo $MIN_ADA
# Out:
# 2000000

# %% [markdown]
# ### Contract Parameters

# %% [markdown]
# Set parameters for the contract. This contract scales to large numbers of lenders and borrowers, but that will involve many transactions and much time if run on-chain.

# %%
N_LENDERS=30
N_BORROWERS=70

MINIMUM_INVESTMENT=500000
MAXIMUM_INVESTMENT=5000000

POOL_SIZE=$((N_LENDERS * MAXIMUM_INVESTMENT))

MINIMUM_LOAN=100000
MAXIMUM_LOAN=1000000
BORROWER_DJED=500000

TOTAL_DJED=$((POOL_SIZE + N_BORROWERS * BORROWER_DJED))

SETUP_DEADLINE=$((NOW + 1 * HOUR))

INVESTMENT_DEADLINE=$((NOW + 3 * HOUR))
INVESTMENT_REPAYMENT_DEADLINE=$((NOW + 12 * HOUR))

LOAN_DEADLINE=$((NOW + 6 * HOUR))
LOAN_REPAYMENT_DEADLINE=$((NOW + 9 * HOUR))

ULTIMATE_DEADLINE=$((NOW + 15 * HOUR))

# %% [markdown]
# ### Keys for the Administrator

# %% [markdown]
# Use a pre-existing key for payment.

# %%
ADMIN_ROLE=A
ADMIN_SKEY=christopher-marlowe.skey
ADMIN_VKEY=christopher-marlowe.vkey
ADMIN_ADDR=$(cat christopher-marlowe.testnet.address)
echo $ADMIN_ADDR
# Out:
# addr_test1vrssw4edcts00kk6lp7p5n64666m23tpprqaarmdwkaq69gfvqnpz

# %% [markdown]
# Send 25 Ada to the administrator for each lender and borrower, just to make sure there is sufficient Ada to cover transaction fees.

# %%
marlowe-cli util faucet --lovelace $((25 * (N_LENDERS + N_BORROWERS) * ADA)) --out-file /dev/null --submit 600 $ADMIN_ADDR
# Out:
# TxId "e35b3bce34ab586d6456dd55af940a794dabace6503536d0ad4ad9d2cb9edb57"

# %% [markdown]
# ### Key Derivation

# %% [markdown]
# We'll derive all of the keys for lenders and borrowers from a single root private key.

# %%
ROOT_PRV=william-shakespeare.root.prv

# %% [markdown]
# For the convenience of viewing transactions in Daedalus, we'll include the same stake credential in all of the addresses.

# %%
cardano-wallet key child 1852H/1815H/0H/2/0 < $ROOT_PRV \
| cardano-cli key convert-cardano-address-key --shelley-stake-key --signing-key-file /dev/stdin --out-file /dev/stdout \
| cardano-cli key verification-key --signing-key-file /dev/stdin --verification-key-file /dev/stdout \
| cardano-cli key non-extended-key --extended-verification-key-file /dev/stdin --verification-key-file william-shakespeare.stake.vkey
cardano-cli stake-address build --testnet-magic $CARDANO_TESTNET_MAGIC --stake-verification-key-file william-shakespeare.stake.vkey
# Out:
# stake_test1urplvp2a7dythh6yxutd0qlzzkncr3gy5ftvxj02d3etafqjugc5h

# %% [markdown]
# ### Keys for Lenders

# %% [markdown]
# Build the signing keys and payment addresses for the lenders from the `1852H/1815H/0H/0/` sequence of key derivations.

# %%
mkdir -p tmp
for j in `seq 1 $N_LENDERS`
do
  LENDER_SKEY[$j]=tmp/lender-$j.skey
  LENDER_ADDR[$j]=$(
  cardano-wallet key child 1852H/1815H/0H/0/$j < $ROOT_PRV \
  | cardano-cli key convert-cardano-address-key --shelley-payment-key --signing-key-file /dev/stdin --out-file ${LENDER_SKEY[$j]}
  cardano-cli key verification-key --signing-key-file ${LENDER_SKEY[$j]} --verification-key-file /dev/stdout \
  | cardano-cli address build --testnet-magic $CARDANO_TESTNET_MAGIC --payment-verification-key-file /dev/stdin --stake-verification-key-file william-shakespeare.stake.vkey \
  )
  echo "Lender 1852H/1815H/0H/0/$j = ${LENDER_ADDR[$j]}"
done
# Out:
# Lender 1852H/1815H/0H/0/1 = addr_test1qzenwj7elwatk3mmc368mwnv067fqnuk3x7u4nqw5dezg8wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqf6k36p
# Lender 1852H/1815H/0H/0/2 = addr_test1qraxynufcduk7ak7nke2jm6pnc32vn7wsmm7ml30cutfgg7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq77wfgp
# Lender 1852H/1815H/0H/0/3 = addr_test1qzlwepx5u26a8w94kfrkfem6njlam22emyhjscu0lxqrce7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq5jnrn3
# Lender 1852H/1815H/0H/0/4 = addr_test1qqjrjfslev50d5jn6qdeztxsqvuaaefq6e4hu55n59grjj7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqwhulyr
# Lender 1852H/1815H/0H/0/5 = addr_test1qqxrzfv0v8l0lahyc5qsgpug66dafp8njl278g0pter7e3xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqcjuuw0
# Lender 1852H/1815H/0H/0/6 = addr_test1qqqfzyuqkvrr7ajgk887sqac8lgzatc6el9uxke4x5g5dg7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqkmrpwu
# Lender 1852H/1815H/0H/0/7 = addr_test1qp77epd4gy5hrt8pnh6h73se4durwrrkes3u0vj6tycwsq7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq
r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqez5l32
# Lender 1852H/1815H/0H/0/29 = addr_test1qzyp0dv2hq77jvhk4kh3y45g63tfx759ufwcsu892ukvegkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqqun809
# Lender 1852H/1815H/0H/0/30 = addr_test1qp5g75sm5esea8alu07e8c5k63ywns5tq74lvh8ursr48s7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqjpx5tl

# %% [markdown]
# Send 25 ADA to each lender.

# %%
marlowe-cli util faucet --lovelace $((25 * ADA)) --out-file /dev/null --submit 600 ${LENDER_ADDR[@]}
# Out:
# TxId "ca6a39e1af4030df5cba0f3ea99b083198c93bf8f1c2c29ffebe3e18e48d811e"

# %% [markdown]
# ### Keys for Borrowers

# %% [markdown]
# Build the signing keys and payment addresses for the borrowers from the `1852H/1815H/0H/1/` sequence of key derivations.

# %%
mkdir -p tmp
for j in `seq 1 $N_BORROWERS`
do
  BORROWER_SKEY[$j]=tmp/borrower-$j.skey
  BORROWER_ADDR[$j]=$(
    cardano-wallet key child 1852H/1815H/0H/1/$j < $ROOT_PRV \
  | cardano-cli key convert-cardano-address-key --shelley-payment-key --signing-key-file /dev/stdin --out-file ${BORROWER_SKEY[$j]}
  cardano-cli key verification-key --signing-key-file ${BORROWER_SKEY[$j]} --verification-key-file /dev/stdout \
  | cardano-cli address build --testnet-magic $CARDANO_TESTNET_MAGIC --payment-verification-key-file /dev/stdin --stake-verification-key-file william-shakespeare.stake.vkey \
  )
  echo "Borrower 1852H/1815H/0H/1/$j = ${BORROWER_ADDR[$j]}"
done
# Out:
# Borrower 1852H/1815H/0H/1/1 = addr_test1qp7q4e9nlhq08mrugs8pm5uq045e425w72mxhxupq9qqgykr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqjmt3lh
# Borrower 1852H/1815H/0H/1/2 = addr_test1qpzun0s6thsyf9qt0zyfnn50x8kpwutrv20eq8dgx9gt6tkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqfsjdsz
# Borrower 1852H/1815H/0H/1/3 = addr_test1qqpet7s339suufnxmr4vrg09469v30g59yxa70yrkxvrfekr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq37csh4
# Borrower 1852H/1815H/0H/1/4 = addr_test1qppr8ue92zznn2k3v235fuxtpcun9k32g8jn09dsq3ndvawr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqh2lydz
# Borrower 1852H/1815H/0H/1/5 = addr_test1qzcee8xm57tuss5wm3yvxhpk2w7ws3h03c8w2f30tlqahhkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqgtpxaq
# Borrower 1852H/1815H/0H/1/6 = addr_test1qr53gduqpnz38lhkmgq29axxqhttxk653fp7jxhz0c0wpekr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq3ghaj6
# Borrower 1852H/1815H/0H/1/7 = addr_test1qzfturx55xqdm3pu3vwsrvvz26syajjlmpz0whxvll7cw27r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq3j88jz
# Borrower 1852H/1815H/0H/1/8 = addr_test1qzrlr7lcaamcz063j5xwf9wdnm5kypmlnzmdcuzcfmczhzwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqapm5js
# Borrower 1852H/1815H/0H/1/9 = addr_test1qzrektwgnu5emesenmem5076y0n0vpj4atsdgauqwf9cv0wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq9s5lc4
# Borrower 1852H/1815H/0H/1/10 = addr_test1qr8jjv435qdvch6hfhekqjr72k8zz3a28kwl0x6ru44j677r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqclkeju
# Borrower 1852H/1815H/0H/1/11 = addr_test1qrjxdmx7ue35gwvl87cx0mzuxugvctrmyg3r3tu9pkp2v2xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq
r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqh4caqm
# Borrower 1852H/1815H/0H/1/54 = addr_test1qzh3nlgm5yzcdswcanh9q0aq3juu6ylage33qqw4urvwzvxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqj0qyn0
# Borrower 1852H/1815H/0H/1/55 = addr_test1qzknec584v2yyj9n52hhkh5dcryw0kn0nphcd4968gclye7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqgvlpzj
# Borrower 1852H/1815H/0H/1/56 = addr_test1qr2nyw8g6rmaxmmksh2tm3zk98vxp39ga4x5j6u0khshpakr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq362xv4
# Borrower 1852H/1815H/0H/1/57 = addr_test1qp9e5hdef388stkpt9hwt4frzrgx0xzdjcjzk3lfcz77gcxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqn27u6n
# Borrower 1852H/1815H/0H/1/58 = addr_test1qps9yywjsm8gjjf7zxmsqfsrgqyv3779qt88xfqlppgd09kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqxpwtlx
# Borrower 1852H/1815H/0H/1/59 = addr_test1qr4jf3nutcfghcaqcdp8mrug2nuh4exdftej8yfvles8lwwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqhfu886
# Borrower 1852H/1815H/0H/1/60 = addr_test1qz77dm5z66lk7k29ecz70pmyvzmk47ekrvg9zp29sn68v7kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqf0y3cy
# Borrower 1852H/1815H/0H/1/61 = addr_test1qpflz39mjz7pqafjmrrstctdu6ttls3wnhm08y3l7q8cq3wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqc4m7uh
# Borrower 1852H/1815H/0H/1/62 = addr_test1qpqy4lfkd6cl3pkk4elpv70dwxcvy6fd8a4yuj0nx8fqsj7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqhfcnsf
# Borrower 1852H/1815H/0H/1/63 = addr_test1qrs6qvm8jjwvj5kug8zz9mfptuwx84jk47x7qls7a2x6m8kr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqeq78ae
# Borrower 1852H/1815H/0H/1/64 = addr_test1qqy355kwya9vyqyj5f9semme70xes9xg8l2knrddcvnaeakr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq2kmjxt
# Borrower 1852H/1815H/0H/1/65 = addr_test1qq7pmcwtuz6vcyxmpn3xa7cx5vdzfc6jqjzrk0u5rl8ufvxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq7herau
# Borrower 1852H/1815H/0H/1/66 = addr_test1qzmj5e0rzhe2fjc9dvuqxvwqzgt5n2ual23ed6nn6yst4m7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq3nla2z
# Borrower 1852H/1815H/0H/1/67 = addr_test1qq2vtjusl98yfe3v50kltnreedlak94gt85emcl88gyxq4xr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqvhxas5
# Borrower 1852H/1815H/0H/1/68 = addr_test1qq46qa6cgwndcmnshwsp0xnnpt5gk9aplhfxhxp20qf3tkwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqwr43mr
# Borrower 1852H/1815H/0H/1/69 = addr_test1qpwj3g8krzk6glvmmukhfurgs8lpuanx7fj3e80plwnxhhxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqcrqjt0
# Borrower 1852H/1815H/0H/1/70 = addr_test1qzlcawmgetanf3ctuzxwvchpudgqxrl6mxqxrkj7f9a09rxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq05ttc7

# %% [markdown]
# Send 25 ADA to each borrower.

# %%
marlowe-cli util faucet --lovelace $((25 * ADA)) --out-file /dev/null --submit 600 ${BORROWER_ADDR[@]}
# Out:
# TxId "4c7384d54b14df023164375019428df94f32a92ed33be375e947311a0dfc35e5"

# %% [markdown]
# ### Mint the Djed
#
# The contract will use fake Djed for payments.

# %%
DJED_NAME=DjedUSD

# %%
DJED_POLICY=$(
marlowe-cli util mint --required-signer $ADMIN_SKEY \
                      --change-address $ADMIN_ADDR  \
                      --expires 1000000011          \
                      --count $TOTAL_DJED           \
                      --out-file /dev/null          \
                      --submit 600                  \
                      $DJED_NAME                    \
| sed -e 's/^PolicyID "\(.*\)"$/\1/'                \
)
echo 'PolicyID "'$DJED_POLICY'"'
# Out:
# PolicyID "76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf"

# %%
DJED=$DJED_POLICY.$DJED_NAME
echo $DJED
# Out:
# 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.DjedUSD

# %% [markdown]
# In `cardano-cli` the token name is printed in hexadecimal, so we have . . .

# %%
echo $DJED_POLICY.$(echo -n $DJED_NAME | basenc --base16 | tr '[:upper:]' '[:lower:]')
# Out:
# 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344

# %% [markdown]
# ### Distribute the Djed.

# %% [markdown]
# Send Djed to lenders and borrowers.

# %%
TXOUT=()
for j in `seq 1 $N_LENDERS`
do
  TXOUT+=("--tx-out" "${LENDER_ADDR[$j]}+$MIN_ADA+$MAXIMUM_INVESTMENT\ $DJED")
done
for j in `seq 1 $N_BORROWERS`
do
  TXOUT+=("--tx-out" "${BORROWER_ADDR[$j]}+$MIN_ADA+$BORROWER_DJED\ $DJED")
done

# %%
echo marlowe-cli transaction simple --tx-in "$(find_ada $ADMIN_ADDR)"         \
                                    --tx-in "$(find_token $ADMIN_ADDR $DJED)" \
                                    ${TXOUT[@]}                               \
                                    --change-address $ADMIN_ADDR              \
                                    --required-signer $ADMIN_SKEY             \
                                    --out-file /dev/null                      \
                                    --submit 600                              \
| bash
# Out:
# TxId "a4876508d5f197c2fbf678989e51f70b35650b6cf5a70f6bff4908c40d599a91"

# %% [markdown]
# ### Mint the Liquidity Tokens
#
# The contract will use liquidity tokens for bookkeeping.

# %%
LIQUIDITY_NAME=Liquidity

# %%
LIQUIDITY_POLICY=$(
marlowe-cli util mint --required-signer $ADMIN_SKEY \
                      --change-address $ADMIN_ADDR  \
                      --expires 1000000012          \
                      --count $POOL_SIZE            \
                      --out-file /dev/null          \
                      --submit 600                  \
                      $LIQUIDITY_NAME               \
| sed -e 's/^PolicyID "\(.*\)"$/\1/'                \
)
echo 'PolicyID "'$LIQUIDITY_POLICY'"'
# Out:
# PolicyID "5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd"

# %%
LIQUIDITY=$LIQUIDITY_POLICY.$LIQUIDITY_NAME
echo $LIQUIDITY
# Out:
# 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd.Liquidity

# %% [markdown]
# In `cardano-cli` the token name is printed in hexadecimal, so we have . . .

# %%
echo $LIQUIDITY_POLICY.$(echo -n $LIQUIDITY_NAME | basenc --base16 | tr '[:upper:]' '[:lower:]')
# Out:
# 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd.4c6971756964697479

# %% [markdown]
# ### Mint the Role Tokens

# %% [markdown]
# There is one role token for the administrator.

# %%
ADMIN_ROLE=A

# %% [markdown]
# Lender and borrower tokens will be distribute on a just-in-time basis for making deposits and (separately) for making withdrawals. Note that ordering of these is arbitrary and does not necessarily correspond to the lender and borrower addresses.

# %%
for j in `seq 1 $N_LENDERS`
do
  LENDER_DEPOSIT_ROLE[$j]=LD$j
  LENDER_PAYMENT_ROLE[$j]=LP$j
done

# %%
for j in `seq 1 $N_BORROWERS`
do
  BORROWER_DEPOSIT_ROLE[$j]=BD$j
  BORROWER_PAYMENT_ROLE[$j]=BP$j
done

# %% [markdown]
# Mint the role tokens.

# %%
ROLES_POLICY=$(
marlowe-cli util mint --required-signer $ADMIN_SKEY \
                      --change-address $ADMIN_ADDR  \
                      --expires 1000000013          \
                      --out-file /dev/null          \
                      --submit 600                  \
                      $ADMIN_ROLE                   \
                      ${LENDER_DEPOSIT_ROLE[@]}     \
                      ${LENDER_PAYMENT_ROLE[@]}     \
                      ${BORROWER_DEPOSIT_ROLE[@]}   \
                      ${BORROWER_PAYMENT_ROLE[@]}   \
| sed -e 's/^PolicyID "\(.*\)"$/\1/'                \
)
echo 'PolicyID "'$ROLES_POLICY'"'
# Out:
# PolicyID "9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78"

# %% [markdown]
# View the role tokens.

# %%
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $ADMIN_ADDR
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe     0        17382984566 lovelace + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe     1        10000000 lovelace + 150000000 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd.4c6971756964697479 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe     2        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.41 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe     3        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.424431 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe     4        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443130 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe     5        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443131 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe     6        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443132 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe     7        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443133 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe     8        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443134 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe     9        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443135 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    10        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443136 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    11        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443137 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    12        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443138 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    13        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443139 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    14        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.424432 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    15        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443230 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    16        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443231 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    17        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443232 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    18        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443233 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    19        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443234 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    20        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443235 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    21        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443236 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    22        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443237 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    23        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443238 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    24        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443239 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    25        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.424433 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    26        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443330 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    27        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443331 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    28        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443332 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    29        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443333 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    30        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443334 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    31        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443335 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    32        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443336 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    33        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443337 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    34        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443338 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    35        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443339 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    36        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.424434 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    37        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443430 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    38        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443431 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    39        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443432 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    40        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443433 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    41        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443434 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    42        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443435 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    43        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443436 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    44        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443437 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    45        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443438 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    46        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443439 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    47        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.424435 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    48        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443530 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    49        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443531 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    50        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443532 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    51        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443533 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    52        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443534 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    53        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443535 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    54        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443536 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    55        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443537 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    56        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443538 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    57        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443539 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    58        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.424436 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    59        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443630 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    60        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443631 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    61        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443632 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    62        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443633 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    63        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443634 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    64        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443635 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    65        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443636 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    66        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443637 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    67        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443638 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    68        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443639 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    69        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.424437 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    70        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443730 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    71        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.424438 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    72        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.424439 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    73        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.425031 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    74        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503130 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    75        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503131 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    76        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503132 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    77        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503133 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    78        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503134 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    79        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503135 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    80        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503136 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    81        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503137 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    82        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503138 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    83        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503139 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    84        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.425032 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    85        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503230 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    86        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503231 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    87        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503232 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    88        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503233 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    89        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503234 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    90        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503235 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    91        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503236 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    92        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503237 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    93        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503238 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    94        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503239 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    95        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.425033 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    96        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503330 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    97        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503331 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    98        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503332 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe    99        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503333 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   100        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503334 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   101        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503335 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   102        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503336 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   103        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503337 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   104        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503338 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   105        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503339 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   106        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.425034 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   107        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503430 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   108        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503431 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   109        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503432 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   110        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503433 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   111        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503434 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   112        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503435 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   113        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503436 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   114        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503437 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   115        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503438 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   116        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503439 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   117        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.425035 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   118        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503530 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   119        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503531 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   120        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503532 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   121        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503533 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   122        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503534 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   123        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503535 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   124        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503536 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   125        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503537 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   126        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503538 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   127        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503539 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   128        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.425036 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   129        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503630 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   130        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503631 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   131        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503632 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   132        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503633 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   133        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503634 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   134        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503635 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   135        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503636 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   136        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503637 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   137        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503638 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   138        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503639 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   139        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.425037 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   140        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503730 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   141        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.425038 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   142        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.425039 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   143        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c4431 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   144        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443130 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   145        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443131 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   146        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443132 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   147        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443133 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   148        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443134 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   149        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443135 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   150        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443136 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   151        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443137 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   152        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443138 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   153        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443139 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   154        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c4432 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   155        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443230 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   156        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443231 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   157        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443232 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   158        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443233 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   159        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443234 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   160        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443235 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   161        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443236 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   162        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443237 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   163        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443238 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   164        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443239 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   165        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c4433 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   166        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443330 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   167        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c4434 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   168        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c4435 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   169        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c4436 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   170        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c4437 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   171        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c4438 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   172        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c4439 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   173        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c5031 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   174        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503130 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   175        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503131 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   176        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503132 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   177        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503133 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   178        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503134 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   179        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503135 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   180        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503136 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   181        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503137 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   182        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503138 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   183        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503139 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   184        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c5032 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   185        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503230 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   186        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503231 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   187        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503232 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   188        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503233 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   189        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503234 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   190        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503235 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   191        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503236 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   192        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503237 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   193        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503238 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   194        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503239 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   195        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c5033 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   196        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503330 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   197        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c5034 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   198        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c5035 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   199        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c5036 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   200        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c5037 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   201        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c5038 + TxOutDatumNone
# c8dd715210871791f53e2a85902cba7e523a2113044c5e5e7e992e1b1a7b6cbe   202        10000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c5039 + TxOutDatumNone

# %% [markdown]
# ## Generate the Contract

# %% [markdown]
# Run a Haskell program that generates the contract.

# %%
runhaskell << EOI

{-# LANGUAGE OverloadedStrings  #-}


module CollectiveLoan where


import Control.Monad.Writer (Writer, runWriter, tell)
import Data.Aeson ((.=), encodeFile,object)
import Data.Foldable (foldrM)
import Data.String (fromString)
import Language.Marlowe.CLI.Merkle (deepMerkleize)
import Language.Marlowe.CLI.Types (Continuations)
import Language.Marlowe.Core.V1.Semantics.Types
import Plutus.V1.Ledger.Api (POSIXTime(..))


main :: IO ()
main =
  let
    (contract, continuations) =
      runWriter
        $ makeContract
          $POOL_SIZE $SETUP_DEADLINE
          $N_LENDERS   $MINIMUM_INVESTMENT $MAXIMUM_INVESTMENT $INVESTMENT_DEADLINE     $INVESTMENT_REPAYMENT_DEADLINE
          $N_BORROWERS $MINIMUM_LOAN       $MAXIMUM_LOAN       $LOAN_REPAYMENT_DEADLINE $LOAN_DEADLINE
  in
    encodeFile "collective-loan.merkleization"
      $ object
        [
          "contract"      .= contract
        , "continuations" .= continuations
        ]


djed :: Token
djed = Token "$DJED_POLICY" "$DJED_NAME"

liquidity :: Token
liquidity = Token "$LIQUIDITY_POLICY" "$LIQUIDITY_NAME"

equity :: ValueId
equity = "Equity"

liability :: ValueId
liability = "Liability"

administrator :: Party
administrator = Role "$ADMIN_ROLE"


merkleizeTimeout :: Contract -> Writer Continuations Contract
merkleizeTimeout continuation =
  deepMerkleize
    $ When
      [
        Case (Notify TrueObs )
        continuation
      ]
      (POSIXTime $ULTIMATE_DEADLINE)
      Close


makeContract :: Integer -> Timeout
             -> Int -> Integer -> Integer -> Timeout -> Timeout
             -> Int -> Integer -> Integer -> Timeout -> Timeout
             -> Writer Continuations Contract
makeContract poolSize setupDeadline
         nLenders minimumInvestment maximumInvestment lenderDepositDeadline lenderWithdrawalDeadline
         nBorrowers   minimumLoan       maximumLoan       borrowerDepositDeadline   borrowerWithdrawalDeadline =
  let
    lenders = [1..nLenders]
    borrowers = [1..nBorrowers]
    z c = flip (foldrM (lenderWithdraws maximumInvestment lenderWithdrawalDeadline)) lenders c
  in
    setup poolSize setupDeadline
      =<< flip (foldrM $ lenderDeposits minimumInvestment maximumInvestment lenderDepositDeadline) lenders
      =<< pure . computeLiability
      =<< flip (foldrM $ borrowerWithdraws minimumLoan maximumLoan borrowerWithdrawalDeadline) borrowers
      =<< flip (foldrM $ borrowerDeposits maximumLoan borrowerDepositDeadline) borrowers
      =<< pure . computeEquity
      =<< flip (foldrM $ lenderWithdraws maximumInvestment lenderWithdrawalDeadline) lenders
      =<< merkleizeTimeout Close


setup :: Integer -> Timeout -> Contract -> Writer Continuations Contract
setup poolSize deadline continuation =
  deepMerkleize
    $ When
      [
        Case (Deposit administrator administrator liquidity $ Constant poolSize)
          continuation
      ]
      deadline
      Close


computeLiability :: Contract -> Contract
computeLiability =
  Let "Liability"
    $ AvailableMoney administrator djed


computeEquity :: Contract -> Contract
computeEquity =
  Let "Equity"
    $ AvailableMoney administrator djed


borrowerDeposits :: Integer -> Timeout -> Int -> Contract -> Writer Continuations Contract
borrowerDeposits maximumLoan deadline i continuation =
  let
    name = "Borrower Deposit"
    choice = ChoiceId (fromString name) administrator
    amount = ChoiceValue choice
    borrower = Role . fromString $ "BD" <> show i
  in
    deepMerkleize
      . When
        [
          Case (Choice choice [Bound 1 $ 2 * maximumLoan])
            $ When
               [
                 Case (Deposit administrator borrower djed amount)
                   continuation
               ]
               deadline
               continuation
        ]
        deadline
        =<< merkleizeTimeout continuation


borrowerWithdraws :: Integer -> Integer -> Timeout -> Int -> Contract -> Writer Continuations Contract
borrowerWithdraws minimumLoan maximumLoan deadline i continuation =
  let
    name = "Borrower Withdrawal"
    choice = ChoiceId (fromString name) administrator
    amount = ChoiceValue choice
    borrower = Role . fromString $ "BP" <> show i
  in
    deepMerkleize
      . When
        [
          Case (Choice choice [Bound minimumLoan maximumLoan])
            $ Pay administrator (Party borrower) djed amount
              continuation
        ]
        deadline
        =<< merkleizeTimeout continuation


lenderDeposits :: Integer -> Integer -> Timeout -> Int -> Contract -> Writer Continuations Contract
lenderDeposits minimumInvestment maximumInvestment deadline i continuation =
  let
    name = "Lender Deposit"
    choice = ChoiceId (fromString name) administrator
    amount = ChoiceValue choice
    lender = Role . fromString $ "LD" <> show i
  in
    deepMerkleize
      . When
      [
        Case (Choice choice [Bound minimumInvestment maximumInvestment])
          $ When
              [
                Case (Deposit administrator lender djed amount)
                  $ Pay administrator (Party lender) liquidity amount
                    continuation
              ]
              deadline
              continuation
      ]
      deadline
      =<< merkleizeTimeout continuation


lenderWithdraws :: Integer -> Timeout -> Int -> Contract -> Writer Continuations Contract
lenderWithdraws maximumInvestment deadline i continuation =
  let
    name = "Lender Withdrawal"
    choice = ChoiceId (fromString name) administrator
    amount = ChoiceValue choice
    lender = Role . fromString $ "LP" <> show i
  in
    deepMerkleize
      . When
        [
          Case (Choice choice [Bound 1 $ 2 * maximumInvestment])
            $ When
                [
                  Case (Deposit administrator lender liquidity amount)
                    $ Pay administrator (Party lender) djed
                      (
                        DivValue
                          (MulValue amount $ UseValue equity)
                          (UseValue liability)
                      )
                      continuation
                ]
                deadline
                continuation
        ]
        deadline
        =<< merkleizeTimeout continuation
    
EOI

# %% [markdown]
# How large is the contract?

# %%
ls -lh collective-loan.merkleization
# Out:
# -rw-rw-r-- 1 bbush bbush-upg 333K Aug 14 11:31 collective-loan.merkleization

# %% [markdown]
# How many `Case` statements does it contain?

# %%
sed -e 's/case/&\n/g' collective-loan.merkleization | grep case | wc -l
# Out:
# 1050

# %% [markdown]
# How many merkleizations does it contain?

# %%
jq '.continuations | length' collective-loan.merkleization
# Out:
# 461

# %% [markdown]
# Separate the contract from the merkleizations.

# %%
jq .contract collective-loan.merkleization > collective-loan-1.contract

# %% [markdown]
# ## Set the initial state
#
# The Seller will deposit 2 Ada when the contract is created.

# %%
yaml2json << EOI > collective-loan-1.state
accounts:
- - - role_token: $ADMIN_ROLE
    - currency_symbol: ''
      token_name: ''
  - $MIN_ADA
boundValues: []
choices: []
minTime: $NOW
EOI

# %%
cat collective-loan-1.state
# Out:
# {"accounts":[[[{"role_token":"A"},{"currency_symbol":"","token_name":""}],2000000]],"boundValues":[],"choices":[],"minTime":1660498029000}

# %% [markdown]
# ## Simulate and Execute the Contract

# %% [markdown]
# ### 1. Initialize the contract information
#
# Create a `.marlowe` file that contains all of the information needed to start the contract. Note that we merkleization the contract because of its large size.

# %%
marlowe-cli run initialize --roles-currency $ROLES_POLICY             \
                           --contract-file collective-loan-1.contract \
                           --state-file    collective-loan-1.state    \
                           --out-file      collective-loan-1.partial  \
                           --print-stats
# Out:
# Validator size: 12611
# Base-validator cost: ExBudget {exBudgetCPU = ExCPU 24562825, exBudgetMemory = ExMemory 82600}

# %% [markdown]
# Manually merge the continuations into the `.marlowe` file.

# %%
jq -s '.[0] * .[1]' collective-loan-1.partial collective-loan.merkleization > collective-loan-1.marlowe

# %% [markdown]
# The minimum Ada deposit has been recorded.

# %%
jq .state collective-loan-1.marlowe | json2yaml
# Out:
# accounts:
# - - - role_token: A
#     - currency_symbol: ''
#       token_name: ''
#   - 2000000
# boundValues: []
# choices: []
# minTime: 1660498029000

# %% [markdown]
# Submit the transaction.

# %%
TX_1=$(
marlowe-cli run execute --tx-in "$(find_ada $ADMIN_ADDR)"            \
                        --marlowe-out-file collective-loan-1.marlowe \
                        --change-address $ADMIN_ADDR                 \
                        --required-signer $ADMIN_SKEY                \
                        --out-file /dev/null                         \
                        --submit 600                                 \
| sed -e 's/^TxId "\(.*\)"$/\1/'                                     \
)
echo 'TxId "'$TX_1'"'
# Out:
# TxId "cc66c5bcf405f3c76f9bfc7fc1f8d7a154f772cc8bc335d835453945bd947bf5"

# %% [markdown]
# View the UTxO at the script address.

# %%
SCRIPT_ADDR=$(jq -r .marloweValidator.address collective-loan-1.marlowe)
echo $SCRIPT_ADDR
# Out:
# addr_test1wphttveup3kdrp7ch4e4xjr8jxstwwx20fg8s4epqayylfqga9h6p

# %%
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $SCRIPT_ADDR
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# cc66c5bcf405f3c76f9bfc7fc1f8d7a154f772cc8bc335d835453945bd947bf5     1        2000000 lovelace + TxOutDatumHash ScriptDataInAlonzoEra "ab031567814f9f08b13b8c6c9f0973979d030e4c78d40c7db93ad0d00b88a020"

# %% [markdown]
# ### 2. The administrator deposits the liquidity tokens

# %% [markdown]
# Prepare the transaction.

# %%
marlowe-cli run prepare --deposit-account Role=$ADMIN_ROLE                   \
                        --deposit-party Role=$ADMIN_ROLE                     \
                        --deposit-token $LIQUIDITY                           \
                        --deposit-amount $POOL_SIZE                          \
                        --invalid-before $NOW                                \
                        --invalid-hereafter $((SETUP_DEADLINE - 1 * MINUTE)) \
                        --marlowe-file collective-loan-1.marlowe             \
                        --out-file     collective-loan-2.marlowe             \
                        --print-stats
# Out:
# Datum size: 262

# %% [markdown]
# Now the contract contains both the initial Ada and the liquidity tokens.

# %%
jq .state collective-loan-2.marlowe | json2yaml
# Out:
# accounts:
# - - - role_token: A
#     - currency_symbol: ''
#       token_name: ''
#   - 2000000
# - - - role_token: A
#     - currency_symbol: 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd
#       token_name: Liquidity
#   - 150000000
# boundValues: []
# choices: []
# minTime: 1660498029000

# %% [markdown]
# Submit the transaction.

# %%
TX_2=$(
marlowe-cli run execute --marlowe-in-file collective-loan-1.marlowe           \
                        --tx-in-marlowe "$TX_1#1"                             \
                        --tx-in-collateral "$TX_1#0"                          \
                        --tx-in "$TX_1#0"                                     \
                        --tx-in "$(find_token $ADMIN_ADDR $LIQUIDITY)"        \
                        --tx-in "$(find_role_token $ADMIN_ADDR $ADMIN_ROLE)"  \
                        --tx-out "$(make_role_txout $ADMIN_ADDR $ADMIN_ROLE)" \
                        --marlowe-out-file collective-loan-2.marlowe          \
                        --change-address $ADMIN_ADDR                          \
                        --required-signer $ADMIN_SKEY                         \
                        --out-file /dev/null                                  \
                        --submit 600                                          \
| sed -e 's/^TxId "\(.*\)"$/\1/'                                              \
)
echo 'TxId "'$TX_2'"'
# Out:
# TxId "ed444ca28664dba7c473f2c10015ff01319a7adda12853dd73f09d5f36079c5d"

# %% [markdown]
# View the UTxO at the script address.

# %%
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $SCRIPT_ADDR
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# ed444ca28664dba7c473f2c10015ff01319a7adda12853dd73f09d5f36079c5d     1        2000000 lovelace + 150000000 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd.4c6971756964697479 + TxOutDatumHash ScriptDataInAlonzoEra "ae11c966dbbc5ca2af85747a7c7b69baa7439bef6ca6cad63dc27e959040711f"

# %% [markdown]
# ### 3. The lenders deposit their investment funds

# %% [markdown]
# Lenders deposit in random order.

# %%
INVESTMENT_ORDER=(`seq 1 $N_LENDERS | sort -R`)
echo ${INVESTMENT_ORDER[@]}
# Out:
# 30 23 1 17 24 19 13 8 5 14 28 7 6 27 22 9 29 4 11 18 21 3 26 20 16 10 2 12 15 25

# %% [markdown]
# Lenders deposit random amounts.

# %%
for j in `seq 1 $N_LENDERS`
do
  INVESTMENT_AMOUNT[$j]=$(((MAXIMUM_INVESTMENT - MINIMUM_INVESTMENT) * RANDOM / 32767 + MINIMUM_INVESTMENT))
done
echo ${INVESTMENT_AMOUNT[@]}
# Out:
# 3555528 4785073 4626316 1020081 3644520 1795876 3653859 4724234 3257240 3258201 1418759 4069841 3043412 4428006 1135441 2922421 2115863 2493804 3020477 4076982 3875926 2722052 4464262 2174642 676198 4707754 2148960 2069444 4797845 1766899

# %% [markdown]
# Make the deposits.

# %%
TX_OLD=$TX_2
k=2
for i in `seq 1 $N_LENDERS`
do
  k1=$((k+1))
  k2=$((k+2))
  j=${INVESTMENT_ORDER[$((i-1))]}
  echo
  echo "--- Lender deposit #$i ---"
  ROLE=${LENDER_DEPOSIT_ROLE[$i]}
  ADDR=${LENDER_ADDR[$j]}
  SKEY=${LENDER_SKEY[$j]}
  AMOUNT=${INVESTMENT_AMOUNT[$j]}
  DEADLINE=$((INVESTMENT_DEADLINE - 1 * MINUTE))
  echo "Lender $j requests to deposit $AMOUNT Djed."
  marlowe-cli run prepare --choice-party Role=$ADMIN_ROLE            \
                          --choice-name "Lender Deposit"             \
                          --choice-number $AMOUNT                    \
                          --invalid-before $NOW                      \
                          --invalid-hereafter $DEADLINE              \
                          --marlowe-file collective-loan-$k.marlowe  \
                          --out-file     collective-loan-$k1.marlowe
  echo "Administrator approves deposit and sends role token to lender."
  TX_ADA=$(find_ada $ADMIN_ADDR)
  TX_NEW=$(
  marlowe-cli run execute --marlowe-in-file collective-loan-$k.marlowe          \
                          --tx-in-marlowe "$TX_OLD#1"                           \
                          --tx-in-collateral $TX_ADA                            \
                          --tx-in $TX_ADA                                       \
                          --tx-in "$(find_role_token $ADMIN_ADDR $ADMIN_ROLE)"  \
                          --tx-in "$(find_role_token $ADMIN_ADDR $ROLE)"        \
                          --tx-out "$(make_role_txout $ADMIN_ADDR $ADMIN_ROLE)" \
                          --tx-out "$(make_role_txout $ADDR $ROLE)"             \
                          --marlowe-out-file collective-loan-$k1.marlowe        \
                          --change-address $ADMIN_ADDR                          \
                          --required-signer $ADMIN_SKEY                         \
                          --out-file /dev/null                                  \
                          --submit 600                                          \
  | sed -e 's/^TxId "\(.*\)"$/\1/'                                              \
  )
  echo 'TxId "'$TX_NEW'"'
  TX_OLD=$TX_NEW
  echo "Lender deposits Djed and receives liquidity tokens using their newly-received role token."
  marlowe-cli run prepare --deposit-account Role=$ADMIN_ROLE         \
                          --deposit-party Role=$ROLE                 \
                          --deposit-amount $AMOUNT                   \
                          --deposit-token $DJED                      \
                          --invalid-before $NOW                      \
                          --invalid-hereafter $DEADLINE              \
                          --marlowe-file collective-loan-$k1.marlowe \
                          --out-file     collective-loan-$k2.marlowe 
  TX_ADA=$(find_ada $ADDR)
  CHANGE=$((MAXIMUM_INVESTMENT - AMOUNT))
  TX_NEW=$(
  marlowe-cli run execute --marlowe-in-file collective-loan-$k1.marlowe      \
                          --tx-in-marlowe "$TX_OLD#1"                        \
                          --tx-in-collateral $TX_ADA                         \
                          --tx-in $TX_ADA                                    \
                          --tx-in "$(find_token $ADDR $DJED)"                \
                          --tx-in "$(find_role_token $ADDR $ROLE)"           \
                          --tx-out "$(make_role_txout $ADDR $ROLE)"          \
                          --tx-out "$(make_token_txout $ADDR $DJED $CHANGE)" \
                          --marlowe-out-file collective-loan-$k2.marlowe     \
                          --change-address $ADDR                             \
                          --required-signer $SKEY                            \
                          --out-file /dev/null                               \
                          --submit 600                                       \
  | sed -e 's/^TxId "\(.*\)"$/\1/'                                           \
  )
  echo 'TxId "'$TX_NEW'"'
  TX_OLD=$TX_NEW
  k=$k2
done
# Out:
# --- Lender deposit #1 ---
# Lender 30 requests to deposit 1766899 Djed.
# Administrator approves deposit and sends role token to lender.
# TxId "5dd01d1aa5d46571e922db72df8472bc0b63b024c8ff3147b9523cb5c7d95398"
# Lender deposits Djed and receives liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LD1"
#   Ada: 0.000000
#   5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd."Liquidity": 1766899
# TxId "61cb268abe7fb9182cde676052b77b6fe10a2fbe56dd54d48294324166dd4f76"
#
# --- Lender deposit #2 ---
# Lender 23 requests to deposit 4464262 Djed.
# Administrator approves deposit and sends role token to lender.
# TxId "cebe5688b8d28923d1a7b3c6ffaf7e7d456add9178da14f2482a49b829ade9e7"
# Lender deposits Djed and receives liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LD2"
#   Ada: 0.000000
#   5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd."Liquidity": 4464262
# TxId "513f9980606d579577dddaf2513e6c1cffa4cb25d0a16802237d6586a9f77d71"
#
# --- Lender deposit #3 ---
# Lender 1 requests to deposit 3555528 Djed.
# Administrator approves deposit and sends role token to lender.
# TxId

# Lender deposits Djed and receives liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LD25"
#   Ada: 0.000000
#   5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd."Liquidity": 2922421
# TxId "3639bb495d11495d0c89ff25d3d7c0e715684be02bba23613a7efe2099218971"
#
# --- Lender deposit #26 ---
# Lender 10 requests to deposit 3258201 Djed.
# Administrator approves deposit and sends role token to lender.
# TxId "558b83ee22511862992686d51e68815a5f16ba8bd428421a987d5d581dd2dd80"
# Lender deposits Djed and receives liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LD26"
#   Ada: 0.000000
#   5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd."Liquidity": 3258201
# TxId "47d64527b35420cc178f7a55609302c42dc725cdb2f436b53a314fc2e774f135"
#
# --- Lender deposit #27 ---
# Lender 2 requests to deposit 4785073 Djed.
# Administrator approves deposit and sends role token to lender.
# TxId "df4f2fecb5f4e14c19c75369a60e3959d286c04487981965b123b0ed002a1e28"
# Lender deposits Djed and receives liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LD27"
#   Ada: 0.000000
#   5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd."Liquidity": 4785073
# TxId "983fcff3507c904b28d1b3318833dd9bb47e329704bcfc3a7228abfffdad2b7e"
#
# --- Lender deposit #28 ---
# Lender 12 requests to deposit 4069841 Djed.
# Administrator approves deposit and sends role token to lender.
# TxId "58d8a267775aa4176fa0eec8b16323527f73177c60967d9236899a27e78af3a3"
# Lender deposits Djed and receives liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LD28"
#   Ada: 0.000000
#   5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd."Liquidity": 4069841
# TxId "03cb2f63e77f06bed956fe401d644593227b29e0038538d93725eaf1f51eeb0f"
#
# --- Lender deposit #29 ---
# Lender 15 requests to deposit 1135441 Djed.
# Administrator approves deposit and sends role token to lender.
# TxId "f5ba28d6c59cff7c826fb22af4b9427170b21fbfbd88d4c85b10e38fa1f50f86"
# Lender deposits Djed and receives liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LD29"
#   Ada: 0.000000
#   5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd."Liquidity": 1135441
# TxId "f4013efc569ac20514f30bd4952f210c0b34733d3f01071d888ec7624711da10"
#
# --- Lender deposit #30 ---
# Lender 25 requests to deposit 676198 Djed.
# Administrator approves deposit and sends role token to lender.
# TxId "86060a1604a8676005539e7011247e4f96cdf84db662440b49b135f1b634d769"
# Lender deposits Djed and receives liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LD30"
#   Ada: 0.000000
#   5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd."Liquidity": 676198
# TxId "e136662c1329cbd8988ba3fc049394f77aa6375281acb3f8afe51d7f78b01e5d"

# %% [markdown]
# View the state of the contract.

# %%
jq .state collective-loan-$k.marlowe | json2yaml
# Out:
# accounts:
# - - - role_token: A
#     - currency_symbol: ''
#       token_name: ''
#   - 2000000
# - - - role_token: A
#     - currency_symbol: 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd
#       token_name: Liquidity
#   - 57550084
# - - - role_token: A
#     - currency_symbol: 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf
#       token_name: DjedUSD
#   - 92449916
# boundValues:
# - - Liability
#   - 92449916
# choices:
# - - choice_name: Lender Deposit
#     choice_owner:
#       role_token: A
#   - 676198
# minTime: 1660498029000

# %% [markdown]
# View the UTxO at the script address.

# %%
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $SCRIPT_ADDR
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# e136662c1329cbd8988ba3fc049394f77aa6375281acb3f8afe51d7f78b01e5d     1        2000000 lovelace + 57550084 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd.4c6971756964697479 + 92449916 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumHash ScriptDataInAlonzoEra "a47490c2f47356dacb04ce4cd22eefe12cbc1e29bf4cdc681ab30e8501673fb1"

# %% [markdown]
# ### 4. The lenders withdraw their liquidity tokens

# %% [markdown]
# The role-payout validator address contains the liquidity tokens that were paid to the lenders.

# %%
ROLES_ADDR=$(jq -r .rolesValidator.address collective-loan-1.marlowe)
echo $ROLES_ADDR
# Out:
# addr_test1wq0fq8ghuemq7cjk4cd3fys20g6ew4ntpv7tpw4fclat8nqs93zsf

# %% [markdown]
# View these payouts.

# %%
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $ROLES_ADDR
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 03cb2f63e77f06bed956fe401d644593227b29e0038538d93725eaf1f51eeb0f     2        1724100 lovelace + 4069841 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd.4c6971756964697479 + TxOutDatumHash ScriptDataInAlonzoEra "a8660a918e0595371c4a4a555526c269a38b9f021312de8a5e465c02335c1642"
# 0dfc40206c1da61a5c0794e94b1a3ab596b66c5f38df1477039d1ddf0e6b7449     2        1724100 lovelace + 2493804 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd.4c6971756964697479 + TxOutDatumHash ScriptDataInAlonzoEra
5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd.4c6971756964697479 + TxOutDatumHash ScriptDataInAlonzoEra "91cb21c5d04423dfa99d3b6903fa8e883aeba804113d1e0edae9d6c5bb104837"

# %% [markdown]
# Withdraw these payouts to the lenders' addresses.

# %%
for i in `seq 1 $N_LENDERS`
do
  j=${INVESTMENT_ORDER[$((i-1))]}
  ROLE=${LENDER_DEPOSIT_ROLE[$i]}
  ADDR=${LENDER_ADDR[$j]}
  SKEY=${LENDER_SKEY[$j]}
  TX_ADA=$(find_ada $ADDR)
  marlowe-cli run withdraw --marlowe-file collective-loan-$((2*j+2)).marlowe \
                           --role-name $ROLE                                 \
                           --tx-in-collateral $TX_ADA                        \
                           --tx-in $TX_ADA                                   \
                           --tx-in $(find_role_token $ADDR $ROLE)            \
                           --tx-out "$(make_role_txout $ADDR $ROLE)"         \
                           --change-address $ADDR                            \
                           --required-signer $SKEY                           \
                           --out-file /dev/null                              \
                           --submit 600
done
# Out:
# TxId "579014ac8b3d3b4d219c2a5251c7728f710bb89260a1927776c253325259a65e"
# TxId "b1fd9a256dcee84a7e56abdd8efe2b68c19698e937befd40d1bac32804c9065a"
# TxId "a39d289baf98d071ea77cb6632bcbca92f1154a7b113aca752df79673014fe1e"
# TxId "f4d3a27809c7012f82a9121ab6f161086f5b45007eb94f1e7848a475cd60def8"
# TxId "388bce6fbc504b0c6f738add83c3d256ca36a309e4dbbbf9f778a5bb368e7072"
# TxId "07f0e7c2a1cdc46d99ba6d3bebe352a9b36363bc5f6b59900610f7c1c5754068"
# TxId "f428bdbfb6045f4c5c326c22f13c8975debced7c593f6814a8e33ffd7c86931c"
# TxId "c3e7d927232840b3b6ad669074ba8328173fc945b3a73a412de2d8339c5507eb"
# TxId "7f2357fcd7cc41ab39b8a7f73703bd627034b03930608fc310a50caef34bb149"
# TxId "53efef7ed7b6c53656795bbf913c34e6bf92e412d2b30108c3c9cd0cd4f85518"
# TxId "3d01ab3ed4ebbe62e983a1d49cf9b0f863b678fbd6a80ba5cfaaa07250c2d404"
# TxId "6447d873c2d763bf10f1863424797e4c1f6c0cb3d22bd4c7483def7b5305bba8"
# TxId "d30ba8539a9c324b601658e3323403eaefe7e532328c860feb0c27b4e7352676"
# TxId "4d7657b71394473fae6311198dd1152cbd5930e289e141efe3d5800ff65c1f1f"
# TxId "391d861df00c75c3e6cd06c3f646a121ef47802556ffab219db2e2e406e4588e"
# TxId "f2ebf6e1a123411b360bd9defa5d600b533ffac7a3bbaaa64e20988d21046ca0"
# TxId "928a7ac32da3ee053d390643d1762cfdfa217edfd90d200316ebb3285a1be77a"
# TxId "b085ea611c6a2d6925c6329cd0eb983f05ca936cbd69f7415baa38308702bf38"
# TxId "b80f648441e77c5ca5a3f269cee27508b0c74ceff379d25d5cab7ab364491273"
# TxId "5a37fea45435ee377ce48f79f653a02350e4f892fc59adccea307bf862d1c30f"
# TxId "a319b5df0a35a93b47e597af4062a18cf332f8148a34160c349617f2219af340"
# TxId "81fa1581fae19fc242093626f4f5ece43db6d78150e2dbe278d32728d731dd9a"
# TxId "d2f48791827b9ff2dd36df002860b58d4fe404b97fa1ace32562f81b5b22e16d"
# TxId "d9cb015e489d18549cf7cc14c8a8b2cddda6ba170029f4f0606e1e57f87a8f1e"
# TxId "a728997829286299f0de7b5dfc45a89498f004986ca13ec36ce4c8c77380636a"
# TxId "2bf539c4da619afafbb89d72fa8e2b0fec569d8e3e90ab8f5aa54513b8ec3e8e"
# TxId "d2f9754fc566cb927ce9fb102c1ea67dada7c41d101e9b1b5382708e4b80045b"
# TxId "4dfd99e4566829ad910a6ff9d75019bd718c546e19db8409f7e54417b73ff0db"
# TxId "42d02bc981dd8dccbff2b0a917d8bee0a13b02c4495236d048575403c82ff10e"
# TxId "503b3ca5b5796fa2502752ea708e7d6905f8c18420a82fc09f6c7e75ade88580"

# %% [markdown]
# There are no UTxOs at the payout address.

# %%
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $ROLES_ADDR
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------

# %% [markdown]
# View the UTxOs at the lenders' addresses to see that they have their role tokens and liquidity tokens.

# %%
for j in `seq 1 $N_LENDERS`
do
  echo
  echo "Lender $j = ${LENDER_ADDR[$j]}"
  cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address ${LENDER_ADDR[$j]}
done
# Out:
# Lender 1 = addr_test1qzenwj7elwatk3mmc368mwnv067fqnuk3x7u4nqw5dezg8wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqf6k36p
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# a39d289baf98d071ea77cb6632bcbca92f1154a7b113aca752df79673014fe1e     0        19375281 lovelace + TxOutDatumNone
# a39d289baf98d071ea77cb6632bcbca92f1154a7b113aca752df79673014fe1e     1        1724100 lovelace + 3555528 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd.4c6971756964697479 + TxOutDatumNone
# a39d289baf98d071ea77cb6632bcbca92f1154a7b113aca752df79673014fe1e     2        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c4433 + TxOutDatumNone
# a6741af95cb0b18f7b8063b4bb85079e35430df91c0f17e952700935d4d9dc75     4        2000000 lovelace + 1444472 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
# a6741af95cb0b18f7b8063b4bb85079e35430df91c0f17e952700935d4d9dc75     5        1500000 lovelace + TxOutDatumHash ScriptDataInAlonzoEra "9506183011962244f0ad4c5b49ee8d0f00e25b919ff3b5306359aab13d19719f"
#
# Lender 2 = addr_test1qraxynufcduk7ak7nke2jm6pnc32vn7wsmm7ml30cutfgg7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq77wfgp
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 983fcff3507c904b28d1b3318833dd9bb47e329704bcfc3a7228abfffdad2b7e     4        2000000 lovelace + 214927 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
# 983fcff3507c904b28d1b3318833dd9bb47e329704bcfc3a7228abfffdad2b7e     5        1500000 lovelace + TxOutDatumHash ScriptDataInAlonzoEra "d36aa75d0b69b1b8b25f4b6cff191cbcf449d71b3b355b18faa64347d130a89a"
# d2f9754fc566cb927ce9fb102c1ea67dada7c41d101e9b1b5382708e4b80045b     0        19374973 lovelace + TxOutDatumNone
# d2f9754fc566cb927ce9fb102c1ea67dada7c41d101e9b1b5382708e4b80045b     1        1724100 lovelace + 4785073 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd.4c6971756964697479 + TxOutDatumNone
# d2f9754fc566cb927ce9fb102c1ea67dada7c41d101e9b1b5382708e4b80045b     2        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443237 + TxOutDatumNone
#
# Lender 3 = addr_test1qzlwepx5u26a8w94kfrkfem6njlam22emyhjscu0lxqrce7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq5jnrn3
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 81fa1581fae19fc242093626f4f5ece43db6d78150e2dbe278d32728d731dd9a     0        19391018 lovelace + TxOutDatumNone
# 81fa1581fae19fc242093626f4f5ece43db6d78150e2dbe278d32728d731dd9a     1        1724100 lovelace + 4626316 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd.4c6971756964697479 + TxOutDatumNone
# 81fa1581fae19fc242093626f4f5ece43db6d78150e2dbe278d32728d731dd9a     2        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443232 + TxOutDatumNone
# f4608ec32ffc2cec1cdb8ebbbf7f67956147460aad4c736bb430d7be80881188     4        2000000 lovelace + 373684 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
#
76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
# 61cb268abe7fb9182cde676052b77b6fe10a2fbe56dd54d48294324166dd4f76     5        1500000 lovelace + TxOutDatumHash ScriptDataInAlonzoEra "bed2ec0539712c86b2588b06bdddd50a7d39598640393a0b681e6f90dbb2db73"

# %% [markdown]
# ### 5. The borrowers withdraw their loan funds

# %% [markdown]
# Borrowers withdraw in random order.

# %%
BORROWER_ORDER=(`seq 1 $N_BORROWERS | sort -R`)
echo ${BORROWER_ORDER[@]}
# Out:
# 49 66 7 64 10 58 53 54 31 23 33 40 2 29 47 15 14 59 11 43 4 56 37 55 57 44 26 48 50 28 41 18 32 65 62 34 13 69 22 17 46 52 67 12 24 70 68 35 3 63 51 27 45 60 21 16 6 5 36 25 61 42 8 30 1 39 20 9 19 38

# %% [markdown]
# Borrowers deposit random amounts.

# %%
for j in `seq 1 $N_BORROWERS`
do
  LOAN_AMOUNT[$j]=$(((MAXIMUM_LOAN - MINIMUM_LOAN) * RANDOM / 32767 + MINIMUM_LOAN))
done
echo ${LOAN_AMOUNT[@]}
# Out:
# 588109 561577 791390 579705 299353 843412 570311 985140 487307 464427 457203 213437 842725 208355 201297 380516 307895 859700 299160 388729 230439 180422 530704 174736 552815 317865 318991 361043 688885 996951 735358 863435 643372 539274 761369 871373 252659 893539 201434 300479 109887 207971 631040 288613 294958 733820 243733 225193 237113 463191 568883 246232 483516 887881 192809 379857 375600 122055 910788 311410 518674 343519 443086 675975 652546 835694 165617 471431 333301 673943

# %% [markdown]
# Make the withdrawals.

# %%
for i in `seq 1 $N_BORROWERS`
do
  k1=$((k+1))
  j=${BORROWER_ORDER[$((i-1))]}
  echo
  echo "--- Borrower withdrawal #$i ---"
  ROLE=${BORROWER_PAYMENT_ROLE[$i]}
  ADDR=${BORROWER_ADDR[$j]}
  SKEY=${BORROWER_SKEY[$j]}
  AMOUNT=${LOAN_AMOUNT[$j]}
  echo "Borrower $j requests loan of $AMOUNT Djed."
  echo "Administrator checks credit."
  echo "Administator approves loan and sends role token to borrower."
  DEADLINE=$((LOAN_DEADLINE - 1 * MINUTE))
  marlowe-cli run prepare --choice-party Role=$ADMIN_ROLE            \
                          --choice-name "Borrower Withdrawal"        \
                          --choice-number $AMOUNT                    \
                          --invalid-before $NOW                      \
                          --invalid-hereafter $DEADLINE              \
                          --marlowe-file collective-loan-$k.marlowe  \
                          --out-file     collective-loan-$k1.marlowe
  TX_ADA=$(find_ada $ADMIN_ADDR)
  TX_NEW=$(
  marlowe-cli run execute --marlowe-in-file collective-loan-$k.marlowe          \
                          --tx-in-marlowe "$TX_OLD#1"                           \
                          --tx-in-collateral $TX_ADA                            \
                          --tx-in $TX_ADA                                       \
                          --tx-in "$(find_role_token $ADMIN_ADDR $ADMIN_ROLE)"  \
                          --tx-in "$(find_role_token $ADMIN_ADDR $ROLE)"        \
                          --tx-out "$(make_role_txout $ADMIN_ADDR $ADMIN_ROLE)" \
                          --tx-out "$(make_role_txout $ADDR $ROLE)"             \
                          --marlowe-out-file collective-loan-$k1.marlowe        \
                          --change-address $ADMIN_ADDR                          \
                          --required-signer $ADMIN_SKEY                         \
                          --out-file /dev/null                                  \
                          --submit 600                                          \
  | sed -e 's/^TxId "\(.*\)"$/\1/'                                              \
  )
  echo 'TxId "'$TX_NEW'"'
  TX_OLD=$TX_NEW
  echo "Borrower withdraws the Djed from the payout address using their newly-received role token."
  TX_ADA=$(find_ada $ADDR)
  marlowe-cli run withdraw --marlowe-file collective-loan-$k1.marlowe \
                           --role-name $ROLE                          \
                           --tx-in-collateral $TX_ADA                 \
                           --tx-in $TX_ADA                            \
                           --tx-in $(find_role_token $ADDR $ROLE)     \
                           --tx-out "$(make_role_txout $ADDR $ROLE)"  \
                           --change-address $ADDR                     \
                           --required-signer $SKEY                    \
                           --out-file /dev/null                       \
                           --submit 600
  k=$k1
done
# Out:
# --- Borrower withdrawal #1 ---
# Borrower 49 requests loan of 237113 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP1"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 237113
# TxId "c39e0d9ab5c9a6f392a12b9984c8838644a03820511744488a04f8238cf19eef"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "36c39904c378191444dbf2be1feebdc0a4cefd831ec1b20ec346b2aec038417c"
#
# --- Borrower withdrawal #2 ---
# Borrower 66 requests loan of 835694 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP2"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 835694
# TxId "9220d4768a328c6241fc8eb58b064dd1fcabf1329640424ab2015ba541d511ec"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "5ccf22f94c9422c46ed962cc3692de5a50ef668d6dc396b8cf0f9acf61266b8d"
#
# --- Borrower withdrawal #3 ---
# Borrower 7 requests loan of 570311 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP3"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 570311
# TxId "cba6de16f78c28aefb0e33798070f2c79fb65da08abde39e502eaad16ef5dac2"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "460372c0be11be35a6f6aed45c145fc3bc0f32abcd2ebc71d4d4efb5a7767867"
#
# --- Borrower withdrawal #4 ---
# Borrower 64 requests loan of 675975 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP4"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 675975
# TxId "4d8082ea97d5362c20a9ed26b47e764d0eff4959c0d8fd2d2c2cfa9c2aa4b251"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "ca47cfd23f79638528fa4607e907b484321b3b9273c290306b042b9917f29354"
#
# --- Borrower withdrawal #5 ---
# Borrower 10 requests loan of 464427 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP5"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 464427
# TxId "979932d3e643df47b7be084add080c3852e01eee1dc22c35298505722767d8b1"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "c1f7363a8374d34b8c86cb5dbc547739f7537e305e61672ebe7438b7be5f38ad"
#
# --- Borrower withdrawal #6 ---
# Borrower 58 requests loan of 122055 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP6"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 122055
# TxId "c2f07bef2ae90bb3afee0f59a87d94f7a8900f98b9566bb6670b5026626f5642"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "acd95d5787048bdce59de37249fc59d35f3859764943d5b10723faa39975b0b6"
#
# --- Borrower withdrawal #7 ---
# Borrower 53 requests loan of 483516 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP7"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 483516
# TxId "67d5daca4993328540be5ca968ab3fb3548914c7bf3f35c775587ef64c00f007"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "adb5fedc0406f73da906440d30be31dce1394422862a6a93617cf76f10c2bc45"
#
# --- Borrower withdrawal #8 ---
# Borrower 54 requests loan of 887881 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP8"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 887881
# TxId "c2d93096979a4624126d5ddcf82e0e6efb94ca4f6e7426366ae8f9a566a611e7"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "eb69ca643d8634ce75a5ac318d7ab1da1099c099c8cb89b3fe983e7617430ebb"
#
# --- Borrower withdrawal #9 ---
# Borrower 31 requests loan of 735358 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP9"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 735358
# TxId "5a367dc3ef72b56ef561b161744fd87232aa3ca7e343b000eb32f23fb49f72df"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "46989ba9555fb6519acbaf2023231f62f04ac7dbc02e8993637e7ea3bc11d953"
#
# --- Borrower withdrawal #10 ---
# Borrower 23 requests loan of 530704 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP10"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 530704
# TxId "867672761f4370c712658b8e00b29e61f03a53cdc66d372b76864da19d7a51b1"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "d41da31d408ac64b018bdf871f3004f137cf0d76d527f9147b0002adc17a298e"
#
# --- Borrower withdrawal #11 ---
# Borrower 33 requests loan of 643372 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP11"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 643372
# TxId "acfbb568036381955c43dad49928e9e192ef3d1758a81ee6e46c19de6a1ff6a8"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "ecaa9b81ee30cc483c7456314bdd1534a89233f43531aa0687ab5232a9aaa7df"
#
# --- Borrower withdrawal #12 ---
# Borrower 40 requests loan of 300479 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP12"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 300479
# TxId "6bc4cd3a12bc9855e3dd60485396ccc25d82368233ca2a6e882627635bececf4"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "8bc432bb50579393fdea7e0bdb65a6d03b421ae999dff5d8c15b166cb9dcf7e3"
#
# --- Borrower withdrawal #13 ---
# Borrower 2 requests loan of 561577 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP13"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 561577
# TxId "437fcf00df2bd8f28a4505b76031375c49539b3b266462e936219a015e42b921"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "4d19fa3de8ff655a19abd10ede16186681363672b9638a422da1c3af1b331063"
#
# --- Borrower withdrawal #14 ---
# Borrower 29 requests loan of 688885 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP14"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 688885
# TxId "a92bace1e89b919a840815058e3af929d092d908991b7e6545722a36fbfe16a2"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "1b72e29077ce3b9d7a72c381dde98ae7c42f06ce958201679d07c6aa0beb9370"
#
# --- Borrower withdrawal #15 ---
# Borrower 47 requests loan of 243733 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP15"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 243733
# TxId "5a8084bf382cd4487fb669fbdc144a023d35ac682d64c60430d576577890ff67"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "37b83d4c70f68b2f13e841c4a405499a85baddb0594723b90e314a3dc3943744"
#
# --- Borrower withdrawal #16 ---
# Borrower 15 requests loan of 201297 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP16"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 201297
# TxId "802012b1cdc438f65d4a2dfe049e1169d679d457058125e0afc763cec76e714b"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "f82077fbd1a91172d8e1c7d280ba4698df7a473bd41f7fd943052f85731ebc1a"
#
# --- Borrower withdrawal #17 ---
# Borrower 14 requests loan of 208355 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP17"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 208355
# TxId "d2e35996c4d49e40b351106d0166d5de314832a5e95233492577d655283a7aec"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "5cbd2c2fc9ad8fbeaf2dd0570caff9ef3c3ee47b441d8ca52df18ea31b4e5016"
#
# --- Borrower withdrawal #18 ---
# Borrower 59 requests loan of 910788 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP18"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 910788
# TxId "dc205ffaea54bb5b3dcb83d16b687e532123f54a62faceb081c73e241138a329"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "2bf16538f0caa61e6df56568a6270f89313ddc2d1b16551da935b37f5db50ccf"
#
# --- Borrower withdrawal #19 ---
# Borrower 11 requests loan of 457203 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP19"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 457203
# TxId "eb84b6ebb75f568371a9210c7e7013bf87e53e81d2f311368916aa99da484a7c"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "ba655569ccc154dfaac1b0cc6a8a44910aef907a2850d57f19826617c9e575ab"
#
# --- Borrower withdrawal #20 ---
# Borrower 43 requests loan of 631040 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP20"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 631040
# TxId "58931270be7df17adcbc2621f0410f6024f0028c613c488028a34b762df97fb7"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "0246c7bc82088c49c8cc6c658188da23a7474aa2bc9d67c686506ee4d28166df"
#
# --- Borrower withdrawal #21 ---
# Borrower 4 requests loan of 579705 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP21"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 579705
# TxId "c53e6ee5e417f559392f82f95361d4a435777a3e72d75a22c86768aa0e01a0b9"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "e6d10c90d941afe930c673898958f9a0648224560ab05f8366d99db719f00274"
#
# --- Borrower withdrawal #22 ---
# Borrower 56 requests loan of 379857 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP22"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 379857
# TxId "9526d82c8e4f447b9a7e8b03a41bca9d3a24c1512d43763802bb5dfb7ddfa1ba"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "55c31802a50141bb35a2a120087fc40a8292540244c94dfeee151c50e43e74d2"
#
# --- Borrower withdrawal #23 ---
# Borrower 37 requests loan of 252659 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP23"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 252659
# TxId "d7154984e66c549385b8087dd9e94e3cc1c516637d5f94d1210619fc5e46e33b"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "2b4d1b0549ca8f516ed7b2295025f5a4f6a6179783248938bf722ffea2e21fc6"
#
# --- Borrower withdrawal #24 ---
# Borrower 55 requests loan of 192809 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP24"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 192809
# TxId "f41a90a315b7e28a3eece827cb4fabf7b73fa6bdb2d1c6588629fbc05c717752"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "2b71ab51f7ba24c3949f885992047be4bdfd0921c31d85f6244951330ad5cf1b"
#
# --- Borrower withdrawal #25 ---
# Borrower 57 requests loan of 375600 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP25"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 375600
# TxId "d884fdc55fbfc752f3b11250b475d976a1d5c71c639c905c28b945962b4d1dc8"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "a2995df01ab9a6de1447ae4e778af9b2dd0cedc600f38a9174266518ab1d76bb"
#
# --- Borrower withdrawal #26 ---
# Borrower 44 requests loan of 288613 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP26"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 288613
# TxId "f5f13987f8c55cd22f98f077dd4c80eb41fc2165b56f05521d31f6b0f2c24940"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "7f5f0e85f295851ac258821eabadfb79c29a6291d143c0d60494f8e3d352490e"
#
# --- Borrower withdrawal #27 ---
# Borrower 26 requests loan of 317865 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP27"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 317865
# TxId "069a20b45634bb76075757e0eb6dae987fc35d654d184d6bad024aee7c2e481c"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "90742a4c0938575317b50c354e4f12afc860c92972526a6252ab57cbe5110c73"
#
# --- Borrower withdrawal #28 ---
# Borrower 48 requests loan of 225193 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP28"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 225193
# TxId "591e6612d1de9236f7650684a2227a52e61f199bbb67e7daab502eec85f6a2ca"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "d0c1bd064a95ecbcd4d56126b06cba40ce5ea16d72faac035c1ff2c39cd53658"
#
# --- Borrower withdrawal #29 ---
# Borrower 50 requests loan of 463191 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP29"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 463191
# TxId "f12e10300895287b9ae078542190297a2ba584eb27ff2bbd81406c25f493eb23"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "d488d0202e909245573edc7d2ea08bc3e9fa2acd29b4e97460ddf1dc2adccfe9"
#
# --- Borrower withdrawal #30 ---
# Borrower 28 requests loan of 361043 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP30"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 361043
# TxId "b4fe3c72a98178f35cd162309368bf4a3f9381286bd30caef29c03c96591f12a"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "e926820c02120815479ac66b026cc315c51c969b37d4cc29f435bc872b817523"
#
# --- Borrower withdrawal #31 ---
# Borrower 41 requests loan of 109887 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP31"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 109887
# TxId "a494c37c9c25ccb318d718f236395cba681fed1812c953e6fefbc31b1f0666bd"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "f144be551e44ce36c8d854d4a3a60a55591862d91f9336132146f03d609715e9"
#
# --- Borrower withdrawal #32 ---
# Borrower 18 requests loan of 859700 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP32"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 859700
# TxId "19a851956b80a6abc1c28c9cce2d7ad22241e802a407143b49b594bc72c4da7b"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "81af18959aaa345eef428391e20bd9bb35c15b101b226bbfa390c11d0ee11dcd"
#
# --- Borrower withdrawal #33 ---
# Borrower 32 requests loan of 863435 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP33"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 863435
# TxId "e719afc75f2e003108e971a2954aaf6d8675e92e2c982fb7bcdda0f57d6769b4"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId

# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "869a123f3fa006447edcc127863d7f4b998c6ca8a4733df972077eeafdcd792f"
#
# --- Borrower withdrawal #45 ---
# Borrower 24 requests loan of 174736 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP45"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 174736
# TxId "dded19c9269a0672937f2619b15e113c437bbf7371a35197920f467e67ce18b4"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "08c9f0271ece9d701c622a963accf0d0c6f98d91723b950e2a43f0cd60ce5617"
#
# --- Borrower withdrawal #46 ---
# Borrower 70 requests loan of 673943 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP46"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 673943
# TxId "062ea3e3b984e6263cb960286ba1707cc4c058bc7b934e23950f53b4e77ac00e"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "77bf50148acb36b6d80f2669d208db87aeeb18fe37609264650b2239f700cf41"
#
# --- Borrower withdrawal #47 ---
# Borrower 68 requests loan of 471431 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP47"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 471431
# TxId "13cf1df49b1ad08a3ab92499580891081b9ced8be9c89264df30b7c0526414c3"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "7cf025a519a062be427f4e589b7004b62ddff52fd0884d874f90a4e0719bf314"
#
# --- Borrower withdrawal #48 ---
# Borrower 35 requests loan of 761369 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP48"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 761369
# TxId "ed8891a0c3bc7ab6ba9b5f412af073f9af7baf1f19bd6c93924483ed80ebcfb3"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "f719f8bf9d9ed3c7bf872f2c1f5f355426eddb95f17489b3a0745b5fb01bc54f"
#
# --- Borrower withdrawal #49 ---
# Borrower 3 requests loan of 791390 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP49"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 791390
# TxId "77e63cadce4735d1c1e85016e8c303328f560daf84d584b1be122b85f932a73e"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "be6214925060f481fe8e42f88afed34f6bcf127ed86c0c0a3ca7ad0550b630dd"
#
# --- Borrower withdrawal #50 ---
# Borrower 63 requests loan of 443086 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP50"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 443086
# TxId "dbbeefd2f14030fce3e7808976e3a409a8921d4c1244665f53935c694fdbd4bf"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "16de04ec1d03860f3b51a5576b738082098043c803526b0c3bc5f07a7328700c"
#
# --- Borrower withdrawal #51 ---
# Borrower 51 requests loan of 568883 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP51"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 568883
# TxId "714db3c7ccfd27c9d332f2e35ef087d7ae0d3d9ff59f84e367a814e42db48d15"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "605ef3fb02c40b36292c85901688670bf0169a033af52321b5bfd355c3e6d5a6"
#
# --- Borrower withdrawal #52 ---
# Borrower 27 requests loan of 318991 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP52"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 318991
# TxId "1666ed56506134e699f8909251c3aff6a15ffb3087da5b2fb553283a293ae7ff"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "54bbd72a7caaa36afa8e21a57547af4b7c65917d771704dd6f811df40840a3ab"
#
# --- Borrower withdrawal #53 ---
# Borrower 45 requests loan of 294958 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP53"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 294958
# TxId "d96d5570e0aacdc0c76a4307d1d80e6b2bffe3b5c0cfedf12047d8c7c9128796"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "4113ffd2e198ff5f166915cdbe359b041d16a47e3608fd9695b3c5d16484bf8f"
#
# --- Borrower withdrawal #54 ---
# Borrower 60 requests loan of 311410 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP54"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 311410
# TxId "93435cf10fcf8aec3da7073509f75a572d2efa4c721ad2473fcd5521038e2f61"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "863b0eb3086ebd0247eec630243cbe6a7c95ddeed3d74a07b403ed0985203674"
#
# --- Borrower withdrawal #55 ---
# Borrower 21 requests loan of 230439 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP55"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 230439
# TxId "191c0e71ec54614828104af983eb5052616060f3c9a32175461722661d4f59f0"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "133e2c1de2f140ccb276d96901c66847c718c475655994e4c17ad556fe2d0708"
#
# --- Borrower withdrawal #56 ---
# Borrower 16 requests loan of 380516 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP56"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 380516
# TxId "d82ebbe3285f1cbba94263d89cdcc114dbb1e4da31fa60059b70b34ac52b6f80"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "b24b12fea72ee3646c037ca7c4f9d40b622464cdbd3c568035c90c9e7d58fa27"
#
# --- Borrower withdrawal #57 ---
# Borrower 6 requests loan of 843412 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP57"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 843412
# TxId "97eb613aaa58c3ca969d0f90972455c1f4e08476dd7951f88d785c07c841a89f"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "41553fcaeeaea5cd0491bca159c49cbd3b9a4dd53594188ccdd5d29822d6c669"
#
# --- Borrower withdrawal #58 ---
# Borrower 5 requests loan of 299353 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP58"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 299353
# TxId "39856e3b5f6027edcfb9adf94cd3c18a1430d104859c0fe46ab4a656a35bcdc9"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "98f7f51d037cef2e0ce396c11bd0870f2dd63a85d39bb0f9a0fb77674083891f"
#
# --- Borrower withdrawal #59 ---
# Borrower 36 requests loan of 871373 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP59"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 871373
# TxId "ec7eb0346b6c0a5af0af6727a64361ef723db5202a4d4c826db4bffcf728f477"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "94b0007c5715ea278513d98af70fb7f0b03415a355958f97533e6245d772f6df"
#
# --- Borrower withdrawal #60 ---
# Borrower 25 requests loan of 552815 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP60"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 552815
# TxId "3488334ec0dca51e7d905a751f171e6f6f8ae5a48a2a1dbac6e1190779120d8b"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "8f7209e7bdb3c8f744a2cf5cce6c57b0c5a2d904dcf09537cc29f234a0b1443d"
#
# --- Borrower withdrawal #61 ---
# Borrower 61 requests loan of 518674 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP61"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 518674
# TxId "fa06fce1c048a5ba8fea457378237c49500a8ceffb9dbb9c9364eca9e8eb5cde"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "234275169520f4e0ba80ab7ff1a1d0c521398f7229bcd2c988f6efcc037c8411"
#
# --- Borrower withdrawal #62 ---
# Borrower 42 requests loan of 207971 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP62"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 207971
# TxId "3a72936de6c4bf7472302e1894dc29bb5c2acf9ad3900e245475ec61988d42c0"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "60d3e41a8ee1a16844bf029b4f622659d828a792e9ce57ea34ad2ca182aac075"
#
# --- Borrower withdrawal #63 ---
# Borrower 8 requests loan of 985140 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP63"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 985140
# TxId "b37ef146631d0531d86f217b1f7926ec031475410b20156bb009e56519b9f5af"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "307d02ad9e53b07271e7f5d1a412a747c61125c64f0b03439f7b1e54bd13c4d3"
#
# --- Borrower withdrawal #64 ---
# Borrower 30 requests loan of 996951 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP64"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 996951
# TxId "af9cb0f683189d16dd030a15b96162c5d293e9d6661d20eddf1aeae0c0aec947"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "cef26218485a8052bf274a1988bcce82dd1dd8930746f7fa9f35a1db006e22a9"
#
# --- Borrower withdrawal #65 ---
# Borrower 1 requests loan of 588109 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP65"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 588109
# TxId "371bf31c2e511723b145303799ba091b683ee0e094f49ebb0faad2457f007239"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "8857c790adebcf6fa85cc56eef308304800cca0996c2aa32ab3f1550f52969e9"
#
# --- Borrower withdrawal #66 ---
# Borrower 39 requests loan of 201434 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP66"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 201434
# TxId "e63e032d5daeff67e8c108cc6c8d5f461b1dd191197b424a59e9139a66ea4daf"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "247946411ca804653c7a6df877f8afcf8650249e2196bf406cd7ded146f6070d"
#
# --- Borrower withdrawal #67 ---
# Borrower 20 requests loan of 388729 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP67"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 388729
# TxId "8e710c9f7823e18f38eeed8a3f7fe31d182cbf4765a9ec59e365bc937b40a888"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "3e4ddd7a60a8c3e1c0dd8b2ec2e83cd4a3a5bb4ed7e5e226b065d60eafbce035"
#
# --- Borrower withdrawal #68 ---
# Borrower 9 requests loan of 487307 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP68"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 487307
# TxId "c9a87c95ef083e3edd13090a198ecd0a2f1df70d39ba553577864e8791aaafcd"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "c24fd5f44adf9c7798faebaec7f32307558c1acfbed0aa03c0e1fb6f33317f87"
#
# --- Borrower withdrawal #69 ---
# Borrower 19 requests loan of 299160 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP69"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 299160
# TxId "96936e60ed339faffb7175ff7b109c686b70d609be965ed956ce266d9f38e8be"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "128e14c2e5a47abb24c9970a8cfb656e0ee4309fbb983d64ca587ab532923758"
#
# --- Borrower withdrawal #70 ---
# Borrower 38 requests loan of 893539 Djed.
# Administrator checks credit.
# Administator approves loan and sends role token to borrower.
# Payment 1
#   Acccount: "A"
#   Payee: Party "BP70"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 893539
# TxId "bdf3678bc6b9a80e382410e7d9043b8e5a0cce9b33c36d38140d61fbf92c43d4"
# Borrower withdraws the Djed from the payout address using their newly-received role token.
# TxId "7c326e493a1b4798197f3652f855eacaee4b3130572bc29d7c50ac85bdfe08ad"

# %% [markdown]
# Now the contract accounts show that some Djed remains.

# %%
jq .state.accounts collective-loan-$k.marlowe | json2yaml
# Out:
# - - - role_token: A
#     - currency_symbol: ''
#       token_name: ''
#   - 2000000
# - - - role_token: A
#     - currency_symbol: 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd
#       token_name: Liquidity
#   - 57550084
# - - - role_token: A
#     - currency_symbol: 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf
#       token_name: DjedUSD
#   - 58676689

# %% [markdown]
# View the UTxO at the script address.

# %%
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $SCRIPT_ADDR
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# bdf3678bc6b9a80e382410e7d9043b8e5a0cce9b33c36d38140d61fbf92c43d4     1        2000000 lovelace + 57550084 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd.4c6971756964697479 + 58676689 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumHash ScriptDataInAlonzoEra "6e24f5d4632d6210c6f5fe1fe89b598491e668de046fd3bd7c8ade7561199094"

# %% [markdown]
# There are no UTxOs at the payout address.

# %%
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $ROLES_ADDR
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------

# %% [markdown]
# View the UTxOs at the borrowers' addresses to see that they have their role tokens and Djed.

# %%
for j in `seq 1 $N_BORROWERS`
do
  echo
  echo "Borrower $j = ${BORROWER_ADDR[$j]}"
  cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address ${BORROWER_ADDR[$j]}
done
# Out:
# Borrower 1 = addr_test1qp7q4e9nlhq08mrugs8pm5uq045e425w72mxhxupq9qqgykr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqjmt3lh
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 8857c790adebcf6fa85cc56eef308304800cca0996c2aa32ab3f1550f52969e9     0        24551679 lovelace + TxOutDatumNone
# 8857c790adebcf6fa85cc56eef308304800cca0996c2aa32ab3f1550f52969e9     1        1689618 lovelace + 588109 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
# 8857c790adebcf6fa85cc56eef308304800cca0996c2aa32ab3f1550f52969e9     2        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503635 + TxOutDatumNone
# a4876508d5f197c2fbf678989e51f70b35650b6cf5a70f6bff4908c40d599a91    31        2000000 lovelace + 500000 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
#
# Borrower 2 = addr_test1qpzun0s6thsyf9qt0zyfnn50x8kpwutrv20eq8dgx9gt6tkr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqfsjdsz
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 
76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
# 77bf50148acb36b6d80f2669d208db87aeeb18fe37609264650b2239f700cf41     2        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503436 + TxOutDatumNone
# a4876508d5f197c2fbf678989e51f70b35650b6cf5a70f6bff4908c40d599a91   100        2000000 lovelace + 500000 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone

# %% [markdown]
# ### 6. The borrowers pay back their funds with interest

# %% [markdown]
# Some time passes, and the borrowers pay back their loans. We randomize the sequence of paybacks and returns.

# %%
BORROWER_ORDER=(`seq 1 $N_BORROWERS | sort -R`)
echo ${BORROWER_ORDER[@]}
# Out:
# 57 69 37 48 59 10 42 24 67 13 33 26 40 7 53 18 70 66 20 43 3 15 32 28 1 65 27 52 22 46 2 16 41 55 68 12 17 25 50 47 39 19 34 31 35 4 51 36 14 8 38 56 6 63 58 29 5 23 60 62 44 54 49 64 30 45 11 9 61 21

# %%
for j in `seq 1 $N_BORROWERS`
do
  INTEREST_PERCENT=$((50 * RANDOM / 32767 - 10))
  RETURN_AMOUNT[$j]=$((${LOAN_AMOUNT[$j]} * (100 + INTEREST_PERCENT) / 100))
done
echo ${LOAN_AMOUNT[@]}
echo ${RETURN_AMOUNT[@]}
# Out:
# 588109 561577 791390 579705 299353 843412 570311 985140 487307 464427 457203 213437 842725 208355 201297 380516 307895 859700 299160 388729 230439 180422 530704 174736 552815 317865 318991 361043 688885 996951 735358 863435 643372 539274 761369 871373 252659 893539 201434 300479 109887 207971 631040 288613 294958 733820 243733 225193 237113 463191 568883 246232 483516 887881 192809 379857 375600 122055 910788 311410 518674 343519 443086 675975 652546 835694 165617 471431 333301 673943
# 629276 505419 830959 660863 305340 1037396 741404 1231425 599387 575889 448058 271064 994415 210438 239543 365295 335605 962864 329076 415940 241960 248982 626230 204441 585983 429117 389169 379095 640663 1046798 882429 975681 701275 496132 700459 949796 290557 1045440 203448 381608 110985 241246 605798 326132 339201 785187 233983 236452 322473 472454 659904 290553 498021 950032 183168 452029 341796 124496 1129377 289611 471993 453445 438655 703014 756953 1002832 168929 471431 463288 673943

# %% [markdown]
# Pay back the loans.

# %%
for i in `seq 1 $N_BORROWERS`
do
  k1=$((k+1))
  k2=$((k+2))
  j=${BORROWER_ORDER[$((i-1))]}
  echo
  echo "--- Borrower deposit #$i ---"
  ROLE=${BORROWER_DEPOSIT_ROLE[$i]}
  ADDR=${BORROWER_ADDR[$j]}
  SKEY=${BORROWER_SKEY[$j]}
  AMOUNT=${RETURN_AMOUNT[$j]}
  DEADLINE=$((LOAN_REPAYMENT_DEADLINE - 1 * MINUTE))
  echo "Borrower $j requests to deposit $AMOUNT DjedUSD."
  marlowe-cli run prepare --choice-party Role=$ADMIN_ROLE            \
                          --choice-name "Borrower Deposit"           \
                          --choice-number $AMOUNT                    \
                          --invalid-before $NOW                      \
                          --invalid-hereafter $DEADLINE              \
                          --marlowe-file collective-loan-$k.marlowe  \
                          --out-file     collective-loan-$k1.marlowe
  echo "Administrator approves deposit and sends role token to borrower."
  TX_ADA=$(find_ada $ADMIN_ADDR)
  TX_NEW=$(
  marlowe-cli run execute --marlowe-in-file collective-loan-$k.marlowe          \
                          --tx-in-marlowe "$TX_OLD#1"                           \
                          --tx-in-collateral $TX_ADA                            \
                          --tx-in $TX_ADA                                       \
                          --tx-in "$(find_role_token $ADMIN_ADDR $ADMIN_ROLE)"  \
                          --tx-in "$(find_role_token $ADMIN_ADDR $ROLE)"        \
                          --tx-out "$(make_role_txout $ADMIN_ADDR $ADMIN_ROLE)" \
                          --tx-out "$(make_role_txout $ADDR $ROLE)"             \
                          --marlowe-out-file collective-loan-$k1.marlowe        \
                          --change-address $ADMIN_ADDR                          \
                          --required-signer $ADMIN_SKEY                         \
                          --out-file /dev/null                                  \
                          --submit 600                                          \
  | sed -e 's/^TxId "\(.*\)"$/\1/'                                              \
  )
  echo 'TxId "'$TX_NEW'"'
  TX_OLD=$TX_NEW
  echo "Borrower makes deposit using their newly-received role token."
  marlowe-cli run prepare --deposit-account Role=$ADMIN_ROLE         \
                          --deposit-party Role=$ROLE                 \
                          --deposit-amount $AMOUNT                   \
                          --deposit-token $DJED                      \
                          --invalid-before $NOW                      \
                          --invalid-hereafter $DEADLINE              \
                          --marlowe-file collective-loan-$k1.marlowe \
                          --out-file     collective-loan-$k2.marlowe 
  TX_ADA=$(find_ada $ADDR)
  CHANGE=$((BORROWER_DJED + LOAN_AMOUNT[$j] - AMOUNT))
  TX_NEW=$(
  marlowe-cli run execute --marlowe-in-file collective-loan-$k1.marlowe      \
                          --tx-in-marlowe "$TX_OLD#1"                        \
                          --tx-in-collateral $TX_ADA                         \
                          --tx-in $TX_ADA                                    \
                          --tx-in "$(find_token $ADDR $DJED)"                \
                          --tx-in "$(find_token_2 $ADDR $DJED)"              \
                          --tx-in "$(find_role_token $ADDR $ROLE)"           \
                          --tx-out "$(make_role_txout $ADDR $ROLE)"          \
                          --tx-out "$(make_token_txout $ADDR $DJED $CHANGE)" \
                          --marlowe-out-file collective-loan-$k2.marlowe     \
                          --change-address $ADDR                             \
                          --required-signer $SKEY                            \
                          --out-file /dev/null                               \
                          --submit 600                                       \
  | sed -e 's/^TxId "\(.*\)"$/\1/'                                           \
  )
  echo 'TxId "'$TX_NEW'"'
  TX_OLD=$TX_NEW
  k=$k2
done
# Out:
# --- Borrower deposit #1 ---
# Borrower 57 requests to deposit 341796 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "162a8645e1f79d722763350c0a411d8bc0ea7bf587ddcc02bf4117b14cb47600"
# Borrower makes deposit using their newly-received role token.
# TxId "0cfcd99201895b33460f5e3439cb7e0f70bb1a876c197329eab35efb4e1892e8"
#
# --- Borrower deposit #2 ---
# Borrower 69 requests to deposit 463288 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "fbcdd1e53b2e707d021723ed97823bf183a3bffcab4920a5cbfebeb7d6d933c5"
# Borrower makes deposit using their newly-received role token.
# TxId "3828cd9741badc0cce2de4517f912d9e40e4a02ffe35cd3a7a338451bda36850"
#
# --- Borrower deposit #3 ---
# Borrower 37 requests to deposit 290557 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "c544f0f05e7ea6399f471e2ce0a16b491e302bb797a2d09f01b0f807971dfc70"
# Borrower makes deposit using their newly-received role token.
# TxId "8ab0ebc748bd425f693c7e96b2a6d8a337764a275eea32629bb6baa06de52e61"
#
# --- Borrower deposit #4 ---
# Borrower 48 requests to deposit 236452 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "7db6e4096f6eb775193d786f5f76159cb6a387c7d353260da0a14a668179cf6a"
# Borrower makes deposit using their newly-received role token.
# TxId "3b1ac6074b39d8c961ca9dcce3cc604b9e9d4001d28554bed7cd00ae30b2bb65"
#
# --- Borrower deposit #5 ---
# Borrower 59 requests to deposit 1129377 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "442e923636988e238cebe2041100f40174ebab86fbec7d79aac6e2514c53e9f9"
# Borrower makes deposit using their newly-received role token.
# TxId "1a92377ed715a340e537f0ba16444d86bdf565433ea82730091b7fcdf35583f6"
#
# --- Borrower deposit #6 ---
# Borrower 10 requests to deposit 575889 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "a89b1ca8edca2dccb614a0fe6b3fd89d9a12ff80fd38f2324a0ba3d197858545"
# Borrower makes deposit using their newly-received role token.
# TxId "ad018568acc3a7dd2ba5623d4c28a8bf60ef34496fb274cd34d8de569b4cca36"
#
# --- Borrower deposit #7 ---
# Borrower 42 requests to deposit 241246 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "40a55f95039e2516cb158937fd1aa857b3a604df5375695e9a44dc28ebcd2f4f"
# Borrower makes deposit using their newly-received role token.
# TxId "91a833e91eafeecbc23bdc517accdc502711b72c6f179e1cca6817bda7aad6e6"
#
# --- Borrower deposit #8 ---
# Borrower 24 requests to deposit 204441 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "db03e29cb76bef05ca7ff40997b5c28e7a6973518c6814308982a8fbeda2ebd6"
# Borrower makes deposit using their newly-received role token.
# TxId "2d7b21ca958ece935586c859c0bfb5fef79562cec41bb79ab48f2526c45e4bdd"
#
# --- Borrower deposit #9 ---
# Borrower 67 requests to deposit 168929 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "949abdf9084d46ce0b1af9e757710149943e4892ba6d891df0761ef1b96b42f0"
# Borrower makes deposit using their newly-received role token.
# TxId "d3a6f339dc521a5dec01bd3352d7e04fa9f0a77e820860ef5a3df512560daef6"
#
# --- Borrower deposit #10 ---
# Borrower 13 requests to deposit 994415 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "c5a31ea80faf0693838a8b8b1c1e2537f6049bea932fb20faff0e355186beb5e"
# Borrower makes deposit using their newly-received role token.
# TxId "cfaac1f6f06bfb061309eb6b2dd7e678e634f2713307b91dff7d57ed6324af02"
#
# --- Borrower deposit #11 ---
# Borrower 33 requests to deposit 701275 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "553d5270d1fc7fb391bb4c3c9cb6da95f034e9b4d5a78da558024423ec08df32"
# Borrower makes deposit using their newly-received role token.
# TxId "33b2b1b8c315d46e7074083a79be0eb2321842351a22d5a9028240d2f995a8aa"
#
# --- Borrower deposit #12 ---
# Borrower 26 requests to deposit 429117 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "be5763087e0653bbbf3fd31c0d9cf1ac41bfbc9a8fb28ebadbf0ab46fd2760de"
# Borrower makes deposit using their newly-received role token.
# TxId "23623573c24ab2a3809b2e35f75ae21db7d5d4af9b4a5f8ea2905d9caa6f41cb"
#
# --- Borrower deposit #13 ---
# Borrower 40 requests to deposit 381608 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "9f5646bc064b9e8c4e48b866d5879125527b94b97848a771ae3d0c7b8c4c55f3"
# Borrower makes deposit using their newly-received role token.
# TxId "1d01f9fd578dcd7ef1ed1e0dfaf86ae63f8b8210e9c3a8a668ec6bc9695b46a7"
#
# --- Borrower deposit #14 ---
# Borrower 7 requests to deposit 741404 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "96a33a8a2ebe0f392a0a06bcdfd499918861b58482231ac15e7b67dbc397ba87"
# Borrower makes deposit using their newly-received role token.
# TxId "4dd750166475e327fffe23f2ab81b9dcd8f922b4394b426910bf0400f2c1b55a"
#
# --- Borrower deposit #15 ---
# Borrower 53 requests to deposit 498021 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "455cc5870caa309dbadbc06e133914380279a03b7ebea5ef566d699f468afdc2"
# Borrower makes deposit using their newly-received role token.
# TxId "31c73709a3e84bfc7a81188988b2d2152b36d20a6f409bcd4a6facd23cc4d1a8"
#
# --- Borrower deposit #16 ---
# Borrower 18 requests to deposit 962864 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "7992ca842c4b7647c8c84979d2803758133d4edf5a9191205daa0ff29645b7cb"
# Borrower makes deposit using their newly-received role token.
# TxId "912a830ef8ba8242fdc0e2ab6866021984404dffb6135bc3807ca8ceb761c718"
#
# --- Borrower deposit #17 ---
# Borrower 70 requests to deposit 673943 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "238c63a36dbe464da735be2033fa9cc2ea836a4fbb5de91192f83ba1d8833039"
# Borrower makes deposit using their newly-received role token.
# TxId "93d8681e9e40fc1b31bad17ab1ad77adb1106c8c070f8165248eeeebec2050c4"
#
# --- Borrower deposit #18 ---
# Borrower 66 requests to deposit 1002832 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "ec059aee2e0104de502c1184f1aa2b669633e83c97a1612f2052490c8a5ff8d2"
# Borrower makes deposit using their newly-received role token.
# TxId "a90d31f6ff0125671fcd3abf096ff3478291ec5839490765ff5d054a52081c8b"
#
# --- Borrower deposit #19 ---
# Borrower 20 requests to deposit 415940 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "bedea9b4e0dc532fbc319797f7dbb8a65e9e54523ea4b2c06c9ac53b89df2ebf"
# Borrower makes deposit using their newly-received role token.
# TxId "3285554be5865b550bdc0b6d23e0d5f3c148e85e2af96f7eb69572c2941beaf0"
#
# --- Borrower deposit #20 ---
# Borrower 43 requests to deposit 605798 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "5647981cfef4a69db3beac12c1ce762e2059f8b157a2b35eb563d62c348a97fc"
# Borrower makes deposit using their newly-received role token.
# TxId "e807dfa32d4c8c7bd4787da386600ac60877e81ab8343562aa52b4e59df27d09"
#
# --- Borrower deposit #21 ---
# Borrower 3 requests to deposit 830959 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "2d9dccdfbfd3ece6c6bb7a2a158904365fa2d2c294c86469e0cf64cbec278b25"
# Borrower makes deposit using their newly-received role token.
# TxId "31947d074fca85e59258a62106aebbded3b1b2bffac01f6023ac24f2a6b394bc"
#
# --- Borrower deposit #22 ---
# Borrower 15 requests to deposit 239543 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "6f1eafa15bef5a55f1f892d3bee301d18749dcc4d75cd5dbdd9583c0174284c5"
# Borrower makes deposit using their newly-received role token.
# TxId "53e6d428eb2d99b9de207cf7bd7004e6a508ec6bce0a93f462a6ccb0a382071e"
#
# --- Borrower deposit #23 ---
# Borrower 32 requests to deposit 975681 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "1daf2652409d1ecdd689d042ecc52780275412c1dca322af5bd327c4b53fc6f2"
# Borrower makes deposit using their newly-received role token.
# TxId "9d5360238df1ffcca7916d995c473d4e8bb87a9ac0f93e8a0cd96e0646dd1e4f"
#
# --- Borrower deposit #24 ---
# Borrower 28 requests to deposit 379095 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "1ccab9e03b2997f790494114e00aeed7fdaa7d1ae07af7a948c6c82197ea582f"
# Borrower makes deposit using their newly-received role token.
# TxId "e8a4b890504955b941527289e6c18eb049e7abca243731f299f8ae4eae4f1e9c"
#
# --- Borrower deposit #25 ---
# Borrower 1 requests to deposit 629276 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "aa88a9f60400abcb94f171f4f34b7378987220d118bfa979e6f7841552cef8a2"
# Borrower makes deposit using their newly-received role token.
# TxId "67af48f3556003b8a235d4cbe87f8c3ab1e9a2f36764196660a9a20b808bb59b"
#
# --- Borrower deposit #26 ---
# Borrower 65 requests to deposit 756953 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "ae0a8a2ad479f76a16aec358f1bfa355f891fe08e5a113c98fcb0e935e49e2ec"
# Borrower makes deposit using their newly-received role token.
# TxId "22b6449358b2f1c3c06ff222aba4c20a44fd7e4e1ed1f4dce0f7d566ab7d094f"
#
# --- Borrower deposit #27 ---
# Borrower 27 requests to deposit 389169 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "5d3729d6310aceabbae3f584147c6bf21687073ba5106953bb3851bb5ac08ff3"
# Borrower makes deposit using their newly-received role token.
# TxId "058f1ed19c5e6a3d55b183260b1766da7500d1fecc585b2db80379fb690811d6"
#
# --- Borrower deposit #28 ---
# Borrower 52 requests to deposit 290553 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "f0d5cef946605358914e0b2cb6b63d5dbbdd48a5df9a3c70729726fabc0ca99a"
# Borrower makes deposit using their newly-received role token.
# TxId "e7c2ccd2fd99bd6d7ed23b5689fd700a9c382f6ec9f404b28a32979b69a8c8d6"
#
# --- Borrower deposit #29 ---
# Borrower 22 requests to deposit 248982 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "83b740ccd97748003bba0b5f2b63d12b7207e75ee1320ba42c87f4da0e9fe848"
# Borrower makes deposit using their newly-received role token.
# TxId "6ad56ce998e675416984f739b231f4997c701fd715686dff193c95cdef044770"
#
# --- Borrower deposit #30 ---
# Borrower 46 requests to deposit 785187 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "d2f7cd5835920089967789b9e6cdf89857b0e82870b6fb98b2daa7ebd96feaf1"
# Borrower makes deposit using their newly-received role token.
# TxId "a2885a8a9e2d27bcbd3869f8bb0c4972c5242e2e794810ea303e9d9603d6258e"
#
# --- Borrower deposit #31 ---
# Borrower 2 requests to deposit 505419 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "be6c92047fac00aa29be2cc731e3bb78b0f0ea53ba86c62c3b651c2eb25a1061"
# Borrower makes deposit using their newly-received role token.
# TxId "8b97389c2150c9e531210c6eb699184a16fd32436294f2c70bb02c3fb887f1a1"
#
# --- Borrower deposit #32 ---
# Borrower 16 requests to deposit 365295 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "ea40e2a04e2160c18fb584cde68cfa28196eecc810e7d187e2ebc27abd006bbf"
# Borrower makes deposit using their newly-received role token.
# TxId "7473911d6d8bf779960c531077a78a5cb2a7fa5089e7e0c11673b7ec9411e8c7"
#
# --- Borrower deposit #33 ---
# Borrower 41 requests to deposit 110985 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "4eb330388a64ba0e0adadf4529dd305fe0e83eb4d3ce5f5b3ca512c6806dbb67"
# Borrower makes deposit using their newly-received role token.
# TxId "4f6a9025e4f425c8c12434f47be5858daa61a7a4df3139946c9b550bccab456f"
#
# --- Borrower deposit #34 ---
# Borrower 55 requests to deposit 183168 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "3a236459bdbab5c8578e75401af1b88196c8326b7b99137214235e02e3528ca4"
# Borrower makes deposit using their newly-received role token.
# TxId "9981f1b57e94cebedf59750279278a12095495e48a1aa77c3d181a59eefb702b"
#
# --- Borrower deposit #35 ---
# Borrower 68 requests to deposit 471431 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "ac6ff8bd3623da2ec0969b2cdfef6097e2cdd9edc4a14fbe365c889de45e1071"
# Borrower makes deposit using their newly-received role token.
# TxId "1a594a0d087d18621da699da7d54361d09a8783cc68dc411b57fd25790350dd2"
#
# --- Borrower deposit #36 ---
# Borrower 12 requests to deposit 271064 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "11f4b3fe6871aa097b4b7840ae2af2947fe384b36893b9d20f1b8aab9659d671"
# Borrower makes deposit using their newly-received role token.
# TxId "0b0cf4b60ace9a5c14f5a8e596137e4fc5baaa35c34dfa76d702f14907df8542"
#
# --- Borrower deposit #37 ---
# Borrower 17 requests to deposit 335605 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "0e49df30e8770d850869ad08f02b6b390457dc56f055db35107dbf8259d41819"
# Borrower makes deposit using their newly-received role token.
# TxId "b3018c38e8cf5a4a8efca877956c3d8b4f7f8363385d351a244f5c130cb7e529"
#
# --- Borrower deposit #38 ---
# Borrower 25 requests to deposit 585983 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "4d8e5c5aca1519c319a21768c471ebccec5f01dc55e5fc51895cedc624b2cedc"
# Borrower makes deposit using their newly-received role token.
# TxId "8fbb3c07984ce928867521f10c6fafeca67ad708bdac2ff5f0a1486b062c079f"
#
# --- Borrower deposit #39 ---
# Borrower 50 requests to deposit 472454 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "852ccbe43ea0a4fe73a2fed9f1d36e7157036c8320292d44cc255155adc64001"
# Borrower makes deposit using their newly-received role token.
# TxId "82af8981277b3b9b4cf31bb8e79332a7f6c5feab1f056988988a1242a2745dc6"
#
# --- Borrower deposit #40 ---
# Borrower 47 requests to deposit 233983 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "314c7530aaf42d98435b3f631c72ab9332f9f9282582e0d04bdf37930892a22f"
# Borrower makes deposit using their newly-received role token.
# TxId "f424ea24d77a126656fe0a9bf4ab77a9e4aa537f4bfa41eb7c0f1a6ddc400341"
#
# --- Borrower deposit #41 ---
# Borrower 39 requests to deposit 203448 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "a89003dfa77e7752b508b4d2360c3142d6e650c54697510b6ceaef0ba1b47cc1"
# Borrower makes deposit using their newly-received role token.
# TxId "2e63c5a03093b6340515d4358564bb8a790eda2ab711f3951f757991e0d0f538"
#
# --- Borrower deposit #42 ---
# Borrower 19 requests to deposit 329076 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "9f6a2bae39fc1105ed168f24772ad6369bc0ae430c41599e2e09791e825a28a2"
# Borrower makes deposit using their newly-received role token.
# TxId "044e90673c4b92c1864d355009b330f2e519a91c16666e1264db755b510d79d1"
#
# --- Borrower deposit #43 ---
# Borrower 34 requests to deposit 496132 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "6305d29de3a2cff5aaf1441566a50803462cb1f98231604b6d73510bdb806460"
# Borrower makes deposit using their newly-received role token.
# TxId "6f653afbfb52baf69d2d49babc2daec1a1ea063cbb8177ce76cf93fffa9bc91a"
#
# --- Borrower deposit #44 ---
# Borrower 31 requests to deposit 882429 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "bf4199d72991f655fc86f60575b68ce0206482f87ae279714b6e4e0ec099c696"
# Borrower makes deposit using their newly-received role token.
# TxId "304e7b5e35e4177baa9e55a770da32b144a6ed0067524695c16bbf73b5563d8a"
#
# --- Borrower deposit #45 ---
# Borrower 35 requests to deposit 700459 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "2eafd5ef63fe3a417c3086041e1dce4f4d370603156f09acc6e9fa4bf1f3c646"
# Borrower makes deposit using their newly-received role token.
# TxId "a8ff89de63a1451b7b5fc850df8697dc1934994e6f27d550aa6ec2e1a1b4acdb"
#
# --- Borrower deposit #46 ---
# Borrower 4 requests to deposit 660863 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "5a886f8841c002f2e1d91c27165d1ca26a104a7e47a39d9a34da80f5dd5ce2cc"
# Borrower makes deposit using their newly-received role token.
# TxId "0866587b639316ddcdf3ed46188ea1ac938a7a3fda47066e2a299ae982cfda37"
#
# --- Borrower deposit #47 ---
# Borrower 51 requests to deposit 659904 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "24390667e8597c3a09ec765277e32350e1c21f3098e6bb31691061c7b62d58cf"
# Borrower makes deposit using their newly-received role token.
# TxId "d117f319ba3f6acd97af4dfeade0026c9498d86e0d40f381c61f14de17271f84"
#
# --- Borrower deposit #48 ---
# Borrower 36 requests to deposit 949796 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "2e96fb83bc19a91a0b948fcf83431944cbc008d909f2645bb600e248874e5172"
# Borrower makes deposit using their newly-received role token.
# TxId "38689edda885cf5fdce6a5b58fba23a3e29240598ca440421173ad760cb3278c"
#
# --- Borrower deposit #49 ---
# Borrower 14 requests to deposit 210438 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "e7d6bd6aef8bebbb69f174b3706cb978682421292033680aaa309f22acacb9e3"
# Borrower makes deposit using their newly-received role token.
# TxId "ddc503cdb99c62cd0a6ef62ee55d20305151064ec8699d317f9c3ea0a6a7a61e"
#
# --- Borrower deposit #50 ---
# Borrower 8 requests to deposit 1231425 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "d8fd89a4907bbcaf3fe683f445b7f9109297517d9b7dd3dbc1a0be9e25344ebf"
# Borrower makes deposit using their newly-received role token.
# TxId "ba84fe81e6d65a57c74693abb11fa49737db81ad7a10053ce08f13b605bd600f"
#
# --- Borrower deposit #51 ---
# Borrower 38 requests to deposit 1045440 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "3ab97d6c8d2e3b64a7cdcda0c2c4532acd158d5efc9293c30866c25a856368ce"
# Borrower makes deposit using their newly-received role token.
# TxId "d3636a7e6fd3a34ea0c362d412d22376a76f40b154df301e9c9baa0063337b3a"
#
# --- Borrower deposit #52 ---
# Borrower 56 requests to deposit 452029 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "f39071797dfa1b940e8ad20c26d589e956ad6e200977ccf8a468350024519237"
# Borrower makes deposit using their newly-received role token.
# TxId "f225fd80e11e8b169dff5cf202f029d7d6110b5022b4fb9b39e55fa4f4027abd"
#
# --- Borrower deposit #53 ---
# Borrower 6 requests to deposit 1037396 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "a93665a4c27920113f7895dd7c2085ff2d1940fbfdd08713d3b447f1e73d1351"
# Borrower makes deposit using their newly-received role token.
# TxId "41955b01ca845bcc058730e25abc26bc59a64a0682c8af6b4e568bd4ea55a283"
#
# --- Borrower deposit #54 ---
# Borrower 63 requests to deposit 438655 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "886785bfd74d63a81625f36bf4bf03f80723266aba6cce92c468f75fcb571796"
# Borrower makes deposit using their newly-received role token.
# TxId "4d0d3b60d4fe72f90ca0713f54049e6dd9d66ae481ce7e93c02af815233ab078"
#
# --- Borrower deposit #55 ---
# Borrower 58 requests to deposit 124496 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "2ba30aaee99e6f558781f9481a3859b385e73ec1ba7d32dd1bc3219759fae8cb"
# Borrower makes deposit using their newly-received role token.
# TxId "96138d7b8f94f2735449b207082def689fb425cee8098e6853129f141a8de9da"
#
# --- Borrower deposit #56 ---
# Borrower 29 requests to deposit 640663 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "40acf27276a64cce99ce58c0020f52eeaa465cf9ad0b327292de4e5b1e747d52"
# Borrower makes deposit using their newly-received role token.
# TxId "b0b7fc091ee1a4f731a451ac4193b5660816b8038312c8689b62581fb01e3318"
#
# --- Borrower deposit #57 ---
# Borrower 5 requests to deposit 305340 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "94b906c3d6e09b2dea3b0074016e779c6bccbd54a1c3a3121322315817340d0d"
# Borrower makes deposit using their newly-received role token.
# TxId "a834e5c1e2502275dc8b227daa939a1f240cd9109d713dc9d4e01db815693577"
#
# --- Borrower deposit #58 ---
# Borrower 23 requests to deposit 626230 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "210b36f7f85c7e26583f04eaba4dc08faf3ec1a78013c95d638a7a1206e11dca"
# Borrower makes deposit using their newly-received role token.
# TxId "c319b5caeb66671fa44f3494322454a35aa0fe12c1bae6964968a20c17271e91"
#
# --- Borrower deposit #59 ---
# Borrower 60 requests to deposit 289611 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "e6016b190a72286782c503c232d4fc38d76bca30d7006796e08d93d53f11fe14"
# Borrower makes deposit using their newly-received role token.
# TxId "2f3b05028d8d14e63a091f08b3152ad04f06366c64a8b49af1fecb91a5557051"
#
# --- Borrower deposit #60 ---
# Borrower 62 requests to deposit 453445 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "9ad8a5c1a7c9a42f24c27c0f6efc50ce7dde1810e527111cba34dfc32d093c7c"
# Borrower makes deposit using their newly-received role token.
# TxId "3c8571033b5c1ff675b7e103d60b1a96e5676ee3dd3bb14b3c9385073ab5a3f3"
#
# --- Borrower deposit #61 ---
# Borrower 44 requests to deposit 326132 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "48dddfd3b8209eda46312071070f4f1800922ecddbc40eadb146df47bb615214"
# Borrower makes deposit using their newly-received role token.
# TxId "49d8d10c758b915eb222035aa3f9c7910bd138c029fbff187a7caa0da4430733"
#
# --- Borrower deposit #62 ---
# Borrower 54 requests to deposit 950032 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "37ce1b91b91c9dce9badbb14135abddf2e01927402d0c84fed07f7c786fc5fa9"
# Borrower makes deposit using their newly-received role token.
# TxId "c8a1e86c9fda89b5c6606794bc828727323f5bc7e0690f3f234aee40278c3100"
#
# --- Borrower deposit #63 ---
# Borrower 49 requests to deposit 322473 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "a4fcc1053fe07a12c2d8d16f7864982cb16b79e94b9eb61f2120ba45aa079bd1"
# Borrower makes deposit using their newly-received role token.
# TxId "6cfb074a4d3eadd75a2cc3722c2dd40bd020212c0d07fe2177dffe1a9f78f332"
#
# --- Borrower deposit #64 ---
# Borrower 64 requests to deposit 703014 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "11c2942f781460172acb28718a02a9e26a024bed20f87003460f416b52797ff7"
# Borrower makes deposit using their newly-received role token.
# TxId "be9902ee83d7c077a408c2216010b2068db439d66d04deb8c7f97f6c455eb784"
#
# --- Borrower deposit #65 ---
# Borrower 30 requests to deposit 1046798 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "d658f276fa9b5471b2e0f1b4a712dab53060be6ff48ba4870c9c24b2e8eb2f42"
# Borrower makes deposit using their newly-received role token.
# TxId "deb6c524327000ddee63a5144ea2a8d916219995f8c5f8a087aeed67a29c60da"
#
# --- Borrower deposit #66 ---
# Borrower 45 requests to deposit 339201 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "d0ad85566517cf265603fd93ad4de4e2178d88b6df26fad390da5bf0d391ec9e"
# Borrower makes deposit using their newly-received role token.
# TxId "71e737c354e172f09f8bbde03ce9876cff3f81fbd34e1dbbfe180ab7a129db95"
#
# --- Borrower deposit #67 ---
# Borrower 11 requests to deposit 448058 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "969f927694579449921ea602fc377cacfa986015a2460ead4e3661e9d466bf38"
# Borrower makes deposit using their newly-received role token.
# TxId "c43609cb997db67efab54587a3cc0f7f218cf45df812ab489e82cba1bdd715e8"
#
# --- Borrower deposit #68 ---
# Borrower 9 requests to deposit 599387 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "6255c961aa595079da1ecf259f302cacb03c996826ce4f76cda54bd4aef1de03"
# Borrower makes deposit using their newly-received role token.
# TxId "2dad091ba2cf6fcfd8301ba2b66fcf4daabca390a89a769283d1f34688c27c84"
#
# --- Borrower deposit #69 ---
# Borrower 61 requests to deposit 471993 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "4a04c22cb2df6535ef3ad5893c36597242a5ea5d622fc99765575abfaeaee2af"
# Borrower makes deposit using their newly-received role token.
# TxId "809c0450c0821f71520fa6f96956f6c436018395b84fe7b5bd20ec128c10dc05"
#
# --- Borrower deposit #70 ---
# Borrower 21 requests to deposit 241960 DjedUSD.
# Administrator approves deposit and sends role token to borrower.
# TxId "556e639e177387c40906cf7e76b86ace36ff8ddee7843eb36a38d083593a7ad5"
# Borrower makes deposit using their newly-received role token.
# TxId "0dfb062d5f9dd42e212e98e2b402e383174a403f5639f334314a5e9326ba931f"

# %% [markdown]
# Now the contract accounts show that the Djed balance has increased.

# %%
jq .state.accounts collective-loan-$k.marlowe | json2yaml
# Out:
# - - - role_token: A
#     - currency_symbol: ''
#       token_name: ''
#   - 2000000
# - - - role_token: A
#     - currency_symbol: 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd
#       token_name: Liquidity
#   - 57550084
# - - - role_token: A
#     - currency_symbol: 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf
#       token_name: DjedUSD
#   - 95982989

# %% [markdown]
# The contract has an excess of assets over liabilities.

# %%
jq .state.boundValues collective-loan-$k.marlowe | json2yaml
# Out:
# - - Liability
#   - 92449916
# - - Equity
#   - 95982989

# %% [markdown]
# View the UTxO at the script address.

# %%
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $SCRIPT_ADDR
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 0dfb062d5f9dd42e212e98e2b402e383174a403f5639f334314a5e9326ba931f     1        2000000 lovelace + 57550084 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd.4c6971756964697479 + 95982989 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumHash ScriptDataInAlonzoEra "86ba6e30538c4c02df0935bd229632db8478700ecaa2eab096c944e28429a20e"

# %% [markdown]
# There are no UTxOs at the payout address.

# %%
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $ROLES_ADDR
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------

# %% [markdown]
# Defragment and then view the UTxOs at the borrowers' addresses to see that they have their role tokens and Djed.

# %%
for j in `seq 1 $N_BORROWERS`
do
  echo
  echo "Borrower $j = ${BORROWER_ADDR[$j]}"
  marlowe-cli util clean --required-signer ${BORROWER_SKEY[$j]} --change-address ${BORROWER_ADDR[$j]} --out-file /dev/null --submit 600
  cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address ${BORROWER_ADDR[$j]}
done
# Out:
# Borrower 1 = addr_test1qp7q4e9nlhq08mrugs8pm5uq045e425w72mxhxupq9qqgykr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqjmt3lh
# TxId "cb983bd4d0e41b1c83cf606cbdce8bb80c0d18348749db969b25b62585dd6a48"
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# cb983bd4d0e41b1c83cf606cbdce8bb80c0d18348749db969b25b62585dd6a48     0        24245700 lovelace + TxOutDatumNone
# cb983bd4d0e41b1c83cf606cbdce8bb80c0d18348749db969b25b62585dd6a48     1        2000000 lovelace + 458833 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
# cb983bd4d0e41b1c83cf606cbdce8bb80c0d18348749db969b25b62585dd6a48     2        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443235 + TxOutDatumNone
# cb983bd4d0e41b1c83cf606cbdce8bb80c0d18348749db969b25b62585dd6a48     3        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42
r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqvhxas5
# TxId "3fbcbd4ab8d6fd4208f7458cce4e9411250eaaac8ea3a853333b8471920eef6a"
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 3fbcbd4ab8d6fd4208f7458cce4e9411250eaaac8ea3a853333b8471920eef6a     0        24266145 lovelace + TxOutDatumNone
# 3fbcbd4ab8d6fd4208f7458cce4e9411250eaaac8ea3a853333b8471920eef6a     1        2000000 lovelace + 496688 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
# 3fbcbd4ab8d6fd4208f7458cce4e9411250eaaac8ea3a853333b8471920eef6a     2        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.424439 + TxOutDatumNone
# 3fbcbd4ab8d6fd4208f7458cce4e9411250eaaac8ea3a853333b8471920eef6a     3        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503433 + TxOutDatumNone
#
# Borrower 68 = addr_test1qq46qa6cgwndcmnshwsp0xnnpt5gk9aplhfxhxp20qf3tkwr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqwr43mr
# TxId "6b5fd6c33a704a9147d00a20ffef16179a5e997e7c425939d2d802d40005286e"
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 6b5fd6c33a704a9147d00a20ffef16179a5e997e7c425939d2d802d40005286e     0        24245612 lovelace + TxOutDatumNone
# 6b5fd6c33a704a9147d00a20ffef16179a5e997e7c425939d2d802d40005286e     1        2000000 lovelace + 500000 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
# 6b5fd6c33a704a9147d00a20ffef16179a5e997e7c425939d2d802d40005286e     2        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443335 + TxOutDatumNone
# 6b5fd6c33a704a9147d00a20ffef16179a5e997e7c425939d2d802d40005286e     3        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503437 + TxOutDatumNone
#
# Borrower 69 = addr_test1qpwj3g8krzk6glvmmukhfurgs8lpuanx7fj3e80plwnxhhxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqcrqjt0
# TxId "5dedf24b7340b82d6f12efc21ec7b58f56683675a8b5c23655ed0e4bc5cd9894"
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 5dedf24b7340b82d6f12efc21ec7b58f56683675a8b5c23655ed0e4bc5cd9894     0        24235642 lovelace + TxOutDatumNone
# 5dedf24b7340b82d6f12efc21ec7b58f56683675a8b5c23655ed0e4bc5cd9894     1        2000000 lovelace + 370013 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
# 5dedf24b7340b82d6f12efc21ec7b58f56683675a8b5c23655ed0e4bc5cd9894     2        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.424432 + TxOutDatumNone
# 5dedf24b7340b82d6f12efc21ec7b58f56683675a8b5c23655ed0e4bc5cd9894     3        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503338 + TxOutDatumNone
#
# Borrower 70 = addr_test1qzlcawmgetanf3ctuzxwvchpudgqxrl6mxqxrkj7f9a09rxr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq05ttc7
# TxId "935f52b9f164301401293aaf89e2026a60e4edccdacd930a03de07074fda9ea8"
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 935f52b9f164301401293aaf89e2026a60e4edccdacd930a03de07074fda9ea8     0        24276115 lovelace + TxOutDatumNone
# 935f52b9f164301401293aaf89e2026a60e4edccdacd930a03de07074fda9ea8     1        2000000 lovelace + 500000 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
# 935f52b9f164301401293aaf89e2026a60e4edccdacd930a03de07074fda9ea8     2        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42443137 + TxOutDatumNone
# 935f52b9f164301401293aaf89e2026a60e4edccdacd930a03de07074fda9ea8     3        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.42503436 + TxOutDatumNone

# %% [markdown]
# ### 7. The lenders redeem their liquidity tokens

# %% [markdown]
# Lenders redeem in random order.

# %%
INVESTMENT_ORDER=(`seq 1 $N_LENDERS | sort -R`)
echo ${INVESTMENT_ORDER[@]}
# Out:
# 18 20 26 8 19 9 29 21 24 3 6 27 10 2 22 1 23 14 7 15 30 25 12 5 17 13 28 4 11 16

# %% [markdown]
# Redeem the proceeds of the investments.

# %%
for i in `seq 1 $N_LENDERS`
do
  k1=$((k+1))
  k2=$((k+2))
  j=${INVESTMENT_ORDER[$((i-1))]}
  echo
  echo "--- Lender redemption #$i ---"
  ROLE=${LENDER_PAYMENT_ROLE[$i]}
  ADDR=${LENDER_ADDR[$j]}
  SKEY=${LENDER_SKEY[$j]}
  AMOUNT=${INVESTMENT_AMOUNT[$j]}
  DEADLINE=$((INVESTMENT_REPAYMENT_DEADLINE - 1 * MINUTE))
  echo "Lender $j requests to deposit $AMOUNT liquidity tokens."
  marlowe-cli run prepare --choice-party Role=$ADMIN_ROLE            \
                          --choice-name "Lender Withdrawal"          \
                          --choice-number $AMOUNT                    \
                          --invalid-before $NOW                      \
                          --invalid-hereafter $DEADLINE              \
                          --marlowe-file collective-loan-$k.marlowe  \
                          --out-file     collective-loan-$k1.marlowe
  echo "Administrator approves deposit and sends role token to lender."
  TX_ADA=$(find_ada $ADMIN_ADDR)
  TX_NEW=$(
  marlowe-cli run execute --marlowe-in-file collective-loan-$k.marlowe          \
                          --tx-in-marlowe "$TX_OLD#1"                           \
                          --tx-in-collateral $TX_ADA                            \
                          --tx-in $TX_ADA                                       \
                          --tx-in "$(find_role_token $ADMIN_ADDR $ADMIN_ROLE)"  \
                          --tx-in "$(find_role_token $ADMIN_ADDR $ROLE)"        \
                          --tx-out "$(make_role_txout $ADMIN_ADDR $ADMIN_ROLE)" \
                          --tx-out "$(make_role_txout $ADDR $ROLE)"             \
                          --marlowe-out-file collective-loan-$k1.marlowe        \
                          --change-address $ADMIN_ADDR                          \
                          --required-signer $ADMIN_SKEY                         \
                          --out-file /dev/null                                  \
                          --submit 600                                          \
  | sed -e 's/^TxId "\(.*\)"$/\1/'                                              \
  )
  echo 'TxId "'$TX_NEW'"'
  TX_OLD=$TX_NEW
  echo "Lender deposits liquidity tokens using their newly-received role token."
  marlowe-cli run prepare --deposit-account Role=$ADMIN_ROLE         \
                          --deposit-party Role=$ROLE                 \
                          --deposit-amount $AMOUNT                   \
                          --deposit-token $LIQUIDITY                 \
                          --invalid-before $NOW                      \
                          --invalid-hereafter $DEADLINE              \
                          --marlowe-file collective-loan-$k1.marlowe \
                          --out-file     collective-loan-$k2.marlowe 
  TX_ADA=$(find_ada $ADDR)
  TX_NEW=$(
  marlowe-cli run execute --marlowe-in-file collective-loan-$k1.marlowe  \
                          --tx-in-marlowe "$TX_OLD#1"                    \
                          --tx-in-collateral $TX_ADA                     \
                          --tx-in $TX_ADA                                \
                          --tx-in "$(find_token $ADDR $LIQUIDITY)"       \
                          --tx-in "$(find_role_token $ADDR $ROLE)"       \
                          --tx-out "$(make_role_txout $ADDR $ROLE)"      \
                          --marlowe-out-file collective-loan-$k2.marlowe \
                          --change-address $ADDR                         \
                          --required-signer $SKEY                        \
                          --out-file /dev/null                           \
                          --submit 600                                   \
  | sed -e 's/^TxId "\(.*\)"$/\1/'                                       \
  )
  echo 'TxId "'$TX_NEW'"'
  TX_OLD=$TX_NEW
  echo "Lender withdraws their funds from the payout address."
  TX_ADA=$(find_ada $ADDR)
  marlowe-cli run withdraw --marlowe-file collective-loan-$k2.marlowe \
                           --role-name $ROLE                          \
                           --tx-in-collateral $TX_ADA                 \
                           --tx-in $TX_ADA                            \
                           --tx-in $(find_role_token $ADDR $ROLE)     \
                           --tx-out "$(make_role_txout $ADDR $ROLE)"  \
                           --change-address $ADDR                     \
                           --required-signer $SKEY                    \
                           --out-file /dev/null                       \
                           --submit 600
  k=$k2
done
# Out:
# --- Lender redemption #1 ---
# Lender 18 requests to deposit 2493804 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "ca43c3b64451dc577a9257c4a0ed8527ad4234293f6a2535ff2aa2b4719e06c9"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP1"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 2589107
# TxId "3be3ecfe79dbb6383aa1bcb12fc4d622413867f68859036e308b9f6eb349a1ce"
# Lender withdraws their funds from the payout address.
# TxId "bb9935408761c67c5b99d90bb41800bdb31fc4e16b708f2e54288a207fb11cd8"
#
# --- Lender redemption #2 ---
# Lender 20 requests to deposit 4076982 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "c539adba7b9913b72b822564ec242a6a7c009f3618c62527810805c0f3ba8bff"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP2"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 4232788
# TxId "d5a6128951ea309a7a06b5d842c47f5a5ef36117eb5a216783ca23b25a8659e9"
# Lender withdraws their funds from the payout address.
# TxId "f446c78b6497934753545a2c6abc251a807973c752dbeab25ff2acf8f082473b"
#
# --- Lender redemption #3 ---
# Lender 26 requests to deposit 4707754 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "220a633ec99c2af60579f53718ea010136084b71437cfff51f48ce5bee98f542"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP3"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 4887666
# TxId "aea2c9f18615a80ba9c2d098acb4b3242955f8bf520f625e032d554ef947a08b"
# Lender withdraws their funds from the payout address.
# TxId "400ecbbc76a601b1a3baef4f0d3acf0946185e7a6d5576aaedb949e7d88a39d8"
#
# --- Lender redemption #4 ---
# Lender 8 requests to deposit 4724234 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "1f9c265cb8a19fed03a69a188263be2c98ee66fdf28c52c404bdbfb780cf10f3"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP4"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 4904776
# TxId "04e731fdb67d6970dbed3f9179fdada7098c8f910d67d2dc5753d56423911cb1"
# Lender withdraws their funds from the payout address.
# TxId "6931ff5c411ccb6371353cad47a469d9b56ad8df9f4b02c48d9d2a27861a02a6"
#
# --- Lender redemption #5 ---
# Lender 19 requests to deposit 3020477 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "aad3aadde35478d8e165b6d1a82411185c64acdb6ecb0a358ff61c3c5d89a4c3"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP5"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 3135908
# TxId "71a16f8aa4e40747f78b116664f97347cc93cfc4fbc41d03737b841fd6fe4978"
# Lender withdraws their funds from the payout address.
# TxId "939694df3d75cad4f7faf6fd14293892bf38298c03362878b604f1d36a080595"
#
# --- Lender redemption #6 ---
# Lender 9 requests to deposit 3257240 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "cb09f8dbe4fbaca183829985832fd9348d03a55c646e32dbe94342f38999b1e8"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP6"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 3381719
# TxId "0aac7149817cdb5017ded95130d25703bbe7805414aeb81aa4de4d8ab3f78048"
# Lender withdraws their funds from the payout address.
# TxId "610e7df307c829e3b3cafa53b6a910f5d4ebffdbe703fe6ea9d3d941128ffb9a"
#
# --- Lender redemption #7 ---
# Lender 29 requests to deposit 4797845 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "7040a6068e07a0e522dbb703c87fac51884cfbe4c7326d589a4c3669b3be9a3e"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP7"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 4981200
# TxId "39410d87237d9f6bd818cdcda1583db1c5e7d5fb307ccb17e52bc1a500061eaf"
# Lender withdraws their funds from the payout address.
# TxId "aaa56c1708fc6fe4d19b50340f2d4c7b390157af02a232c70368eaa958127b5b"
#
# --- Lender redemption #8 ---
# Lender 21 requests to deposit 3875926 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "9548d2c30b47f0cdc38301b49233ea6722063eaacf2f9b373e9ad9c592558161"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP8"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 4024049
# TxId "1e9f860bb49e2cea43e08ec335e0710d48d050b7ca12f7a7ae2235ff62651214"
# Lender withdraws their funds from the payout address.
# TxId "e5bc7957bcc12c213c46b0c67bf36b9fd2f169e4f5ffe606815c02d0578569f5"
#
# --- Lender redemption #9 ---
# Lender 24 requests to deposit 2174642 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "2cc7c0ea7cf0b11fce368dd3591b603932f1542e931e282d4527ddbfa02bddc0"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP9"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 2257748
# TxId "660eac168c27dafef59368f9604a6232db2e606e93c8b1745293785b2f9b05ca"
# Lender withdraws their funds from the payout address.
# TxId "7c4556fb4eb6f41e753c3f0ad6fd886d03c13ea4b42cc1e2a5caca01150b46e8"
#
# --- Lender redemption #10 ---
# Lender 3 requests to deposit 4626316 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "e05c2e5f7da36567ad082454d398fae15ff181bc2b1bc7dcc8894c722b644bde"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP10"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 4803116
# TxId "8a8313b47dbd3f012bf161624e03f2d120ff1bcdd22a16c0b7e58fad79a0c0c2"
# Lender withdraws their funds from the payout address.
# TxId "23f573b79b4890508b6278cefe4f11a28dace334e0447e8d4d650d5373af4770"
#
# --- Lender redemption #11 ---
# Lender 6 requests to deposit 1795876 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "5de5514d148dac288a71df9b795fb5a93b0e9564b640b49380fbb6a15f901f13"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP11"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 1864507
# TxId "60546597455761332b5940dbbd034e7837120bff017d9fed3d0928096709a5b4"
# Lender withdraws their funds from the payout address.
# TxId "d6c7fd0c8ea6fbaa0566de57d9974cf96dd823462a922d15651ccf2492f4f200"
#
# --- Lender redemption #12 ---
# Lender 27 requests to deposit 2148960 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "7940dcaacee5fc1e53d020416129c2b565378aceb05071b2ded71a030293f76b"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP12"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 2231085
# TxId "2c6626a853447563c71ceb67dd7283672a16694958b5035dd256c6304e6493b2"
# Lender withdraws their funds from the payout address.
# TxId "c07b47bea9cb7fb37847fa8ca9fa0f8258bdc716549f0aaae69537e47e293e21"
#
# --- Lender redemption #13 ---
# Lender 10 requests to deposit 3258201 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "68de66d4f36cc528d6f8e53aa8a1e478eeef3663e17714a021c49a0eb5f22aed"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP13"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 3382717
# TxId "9e04b818f1938c690f272a90be3864d7999ba312ad67b16f6e1f9392899b4412"
# Lender withdraws their funds from the payout address.
# TxId "ac246369ac08cab4fd63fba4c15d8aca55970a5db88dc6be08d6d3dce1085ef9"
#
# --- Lender redemption #14 ---
# Lender 2 requests to deposit 4785073 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "9986d4701b5b36ec4aa6278392439bcf9a7c731f4e146f4986d5429c19805c93"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP14"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 4967940
# TxId "1997241e85b4e2518232df261279cfb8c0a46514ffbaa7857d44c51574bda541"
# Lender withdraws their funds from the payout address.
# TxId "f1cd56556ea9afa34cf18e4cbd26357ed6c2b111b5e7b9065f25b4951d2322f2"
#
# --- Lender redemption #15 ---
# Lender 22 requests to deposit 2722052 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "ec3f449f770a52593e7b2d1549c3530c3ddb6c0fba0400259d8cb8d68ecf3632"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP15"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 2826078
# TxId "b7a37ade6e76199922d1bbdba92e461f285b09847f798d68ca6cf7cf825c9ff5"
# Lender withdraws their funds from the payout address.
# TxId "1462a5a18b43d9e08ccf3eb660fca3093e47199a440bad8db486ff229ef3c357"
#
# --- Lender redemption #16 ---
# Lender 1 requests to deposit 3555528 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "cb6adc4a515f3d3072bfa3e85b33e7aa372fb8c59adbabab6dba1f060c68085f"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP16"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 3691406
# TxId "76e5f2e46426377f6c034a44e5164a399d290ac90fbd52f78eb3af929aa965da"
# Lender withdraws their funds from the payout address.
# TxId "6c73adbb86ec220f5fac5e4e8a66585518cbbfb73de9f52dee49115dacd51575"
#
# --- Lender redemption #17 ---
# Lender 23 requests to deposit 4464262 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "46e0c8f6731bb64a750394331d29d6ac988c87004a50e333df85671881424788"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP17"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 4634869
# TxId "db2927b68157e7f1cfb00742f87a5f7c32a1b34f43328e110577106d0c0184af"
# Lender withdraws their funds from the payout address.
# TxId "c8af6a382de077390a8d72b4fa69906456d97fef00addadaf630598b7260d28d"
#
# --- Lender redemption #18 ---
# Lender 14 requests to deposit 4428006 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "802c6ada3863dd534eb7605a4f97fcf5e9fd6c1f8bcba2fc8cf4a38353c81ce1"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP18"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 4597227
# TxId "fa03b786b6ad668c30eae8a06893b8b1ceca63794453ea387ab7e279c577ed33"
# Lender withdraws their funds from the payout address.
# TxId "399269e38dc4f27df23be374a3f032f9709baa66ab67a43018e8a4a33512304e"
#
# --- Lender redemption #19 ---
# Lender 7 requests to deposit 3653859 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "1f879899bdfa4d6903d80e966db1407b1aac0bb193078d97c20ec8849e98fb01"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP19"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 3793495
# TxId "949b17feb54a729f16d6b637736278fb7ca2578dbd46deb43d7a4b074560f8d4"
# Lender withdraws their funds from the payout address.
# TxId "e77ddef910194e94909707d5758d6c1c365ac85a1c082d8b64481fd3dae5c782"
#
# --- Lender redemption #20 ---
# Lender 15 requests to deposit 1135441 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "912b8342eaa7a05a7fe91fdb307b921c87a01b37e331059cd96a7707b7d50dab"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP20"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 1178833
# TxId "3dc5456ab562bdf5cd096d5391554c122ffbc2b4a616674e9d88738092d4d739"
# Lender withdraws their funds from the payout address.
# TxId "36d7c590bba19ea62730ec2615c09f90e2a88cfb0beee6388c69e32afb64f227"
#
# --- Lender redemption #21 ---
# Lender 30 requests to deposit 1766899 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "f4543fb1bc092a23fee14a136169841686e851a4c88528945ac35e2d1fab1686"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP21"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 1834423
# TxId "eaa48a793be8a4ec85778f96260096c51b7efbff61b2415a0b70eb5d047dc199"
# Lender withdraws their funds from the payout address.
# TxId "fc3525350f39312c3cd3911b5a3fc63cf56682fe905c2663422fba1aeefd5130"
#
# --- Lender redemption #22 ---
# Lender 25 requests to deposit 676198 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "356b070de0e96fd7e0d50c324b8a854ac64d109797de480838456dbf8ce9c1da"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP22"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 702040
# TxId "afc00af1fb0d722be720ff272f872de758b71dcb927247f379d278a207f108c2"
# Lender withdraws their funds from the payout address.
# TxId "67f102cef39c7da3a9515b4e6e0536872d9546b6bb3c5ddee83e112b23d7448c"
#
# --- Lender redemption #23 ---
# Lender 12 requests to deposit 4069841 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "e896b021dc741528a900f4ab69c18eb1a0d7333774ce2ae5dfaf5c6ef2bdc9c5"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP23"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 4225374
# TxId "ffd90b157b8b8a4c2d3d7e749d5ab1899d92bb9b5113a6653e6f6e9acdaeb877"
# Lender withdraws their funds from the payout address.
# TxId "533d7eb00149d6ba2469ad06258db61f33162041e6b558a26c2ecae4d42a1733"
#
# --- Lender redemption #24 ---
# Lender 5 requests to deposit 3644520 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "829dadf2fc9ef4ab379a6aae4d01d45f7f7d33755e08e2f299cff7f51c893375"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP24"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 3783799
# TxId "a082a8706225dafb72ec89f3073fb958ebef0c6f1ba8be982f61a698e7d912d5"
# Lender withdraws their funds from the payout address.
# TxId "b3d764893083ca51d81b03866ffb1fada4d0c82d6cf70596af6c6427b5b8acfb"
#
# --- Lender redemption #25 ---
# Lender 17 requests to deposit 2115863 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "4d7c72ca22fcef93e1902d64ac113a6632e6f809e441564c2fbb4a5077443de1"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP25"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 2196723
# TxId "09547ddf3158aa80542333b507e0d211e5316d852bc4bd53ff54ea2890184d02"
# Lender withdraws their funds from the payout address.
# TxId "02ab181ebfdcbd38edb1660357840447b566bda4381c43a704d6c7d3c651de6a"
#
# --- Lender redemption #26 ---
# Lender 13 requests to deposit 3043412 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "01190208fb30034453da85448c3536362df062f15c2790e293e70353169541b7"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP26"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 3159719
# TxId "008fea7ebfd480d1ca946cf6fb1d67b4ef3fb1dcb51fb19c0aa837e90ebefdf5"
# Lender withdraws their funds from the payout address.
# TxId "2910e1fcc96ee993740f67ddd92f42efb5c1b7247922bdeb5e44e7d6e166b2e4"
#
# --- Lender redemption #27 ---
# Lender 28 requests to deposit 2069444 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "5f3d1d170d3b07356ffb83edb0c8837e544a0a4e9b07e69a05ada18bddb1c978"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP27"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 2148530
# TxId "3798314c426f55ffb7e5a75445279a0e5a044f0d56ae886da56f68b1b020f474"
# Lender withdraws their funds from the payout address.
# TxId "79c50ae2a8a1f5de5ceb79a6eda70b04adf377aa61f8de9f2ffa039b777cbce9"
#
# --- Lender redemption #28 ---
# Lender 4 requests to deposit 1020081 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "8f39f4e3a10f3d4fe663449551fa539362479c04a2077c0cba2c034ac63da152"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP28"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 1059064
# TxId "5985f23d8876e5806c822bdbe6e041f19c9d2be5e6644d42d5535ef697e93e99"
# Lender withdraws their funds from the payout address.
# TxId "355757d3b7c9a6ea2a8511e8d0f10fa6cb7c86242b4502218b8af0a97ba2d40e"
#
# --- Lender redemption #29 ---
# Lender 11 requests to deposit 1418759 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "be1fbbc2f2a4442dc283f0b8c91082ddc23c1a874d7c1c8851b5116240c5afb0"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP29"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 1472978
# TxId "acfcfb7d54249ed7c4bcda7d59cb2e7ae0605a3f6895a68d371e217eab9edd28"
# Lender withdraws their funds from the payout address.
# TxId "2270916afea6a9bb4b181d253414bfe2cce3b56d64e5baa6f54c3d9370b131c1"
#
# --- Lender redemption #30 ---
# Lender 16 requests to deposit 2922421 liquidity tokens.
# Administrator approves deposit and sends role token to lender.
# TxId "0ca629388f8605a893df298dd29e68aaa252959cbf0868a219788d7f47f571e4"
# Lender deposits liquidity tokens using their newly-received role token.
# Payment 1
#   Acccount: "A"
#   Payee: Party "LP30"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 3034104
# TxId "a5e8b04a6ee73868ddf30e02e9cdd5506f9aa8e27b033db342dbe3bcbb51df15"
# Lender withdraws their funds from the payout address.
# TxId "b72437c7f0af517a75de52e3e2322cb02a1e0f8601296d7fe8a7a5505dba6c01"

# %% [markdown]
# Now the contract accounts show that the contract only retains the liquidity tokens.

# %%
jq .state.accounts collective-loan-$k.marlowe | json2yaml
# Out:
# - - - role_token: A
#     - currency_symbol: ''
#       token_name: ''
#   - 2000000
# - - - role_token: A
#     - currency_symbol: 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd
#       token_name: Liquidity
#   - 150000000
# - - - role_token: A
#     - currency_symbol: 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf
#       token_name: DjedUSD
#   - 1

# %% [markdown]
# View the UTxO at the script address.

# %%
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $SCRIPT_ADDR
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# a5e8b04a6ee73868ddf30e02e9cdd5506f9aa8e27b033db342dbe3bcbb51df15     1        2000000 lovelace + 150000000 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd.4c6971756964697479 + 1 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumHash ScriptDataInAlonzoEra "00462e61c96777e7c4146446a8a29e8f65bacebc5e325afcf047399d59ae35f2"

# %% [markdown]
# There are no UTxOs at the payout address.

# %%
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $ROLES_ADDR
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------

# %% [markdown]
# Defragment and then view the UTxOs at the lenders' addresses to see that they have their role tokens and liquidity tokens.

# %%
for j in `seq 1 $N_LENDERS`
do
  echo
  echo "Lender $j = ${LENDER_ADDR[$j]}"
  marlowe-cli util clean --required-signer ${LENDER_SKEY[$j]} --change-address ${LENDER_ADDR[$j]} --out-file /dev/null --submit 600
  cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address ${LENDER_ADDR[$j]}
done
# Out:
# Lender 1 = addr_test1qzenwj7elwatk3mmc368mwnv067fqnuk3x7u4nqw5dezg8wr7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqf6k36p
# TxId "7c22fd54a21f3657652fcf2b25c73b65ae173eb78990b1d3e279a681a9cc6db1"
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 7c22fd54a21f3657652fcf2b25c73b65ae173eb78990b1d3e279a681a9cc6db1     0        19625434 lovelace + TxOutDatumNone
# 7c22fd54a21f3657652fcf2b25c73b65ae173eb78990b1d3e279a681a9cc6db1     1        2000000 lovelace + 5135878 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
# 7c22fd54a21f3657652fcf2b25c73b65ae173eb78990b1d3e279a681a9cc6db1     2        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c4433 + TxOutDatumNone
# 7c22fd54a21f3657652fcf2b25c73b65ae173eb78990b1d3e279a681a9cc6db1     3        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503136 + TxOutDatumNone
#
# Lender 2 = addr_test1qraxynufcduk7ak7nke2jm6pnc32vn7wsmm7ml30cutfgg7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq77wfgp
# TxId "50d3af59cc63915e985ddb42e20818b28fef7639c361102f6fbd10d1fb8dc2c0"
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 50d3af59cc63915e985ddb42e20818b28fef7639c361102f6fbd10d1fb8dc2c0     0        19394155 lovelace + TxOutDatumNone
# 50d3af59cc63915e985ddb42e20818b28fef7639c361102f6fbd10d1fb8dc2c0     1        2000000 lovelace + 5182867 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
# 50d3af59cc63915e985ddb42e20818b28fef7639c361102f6fbd10d1fb8dc2c0     2        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443237 + TxOutDatumNone
# 50d3af59cc63915e985ddb42e20818b28fef7639c361102f6fbd10d1fb8dc2c0     3        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503134 + TxOutDatumNone
#
# Lender 3 = addr_test1qzlwepx5u26a8w94kfrkfem6njlam22emyhjscu0lxqrce7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jq5jnrn3
# TxId "3129f42f6596bf2a9aa23df25a7e125587695b0bca86d7719c14bdbff49525a9"
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 

#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 1a0546ce465756200237b7683269eab82446473c26d4aa931349dc8b51d355b4     0        19415725 lovelace + TxOutDatumNone
# 1a0546ce465756200237b7683269eab82446473c26d4aa931349dc8b51d355b4     1        2000000 lovelace + 5183355 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
# 1a0546ce465756200237b7683269eab82446473c26d4aa931349dc8b51d355b4     2        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c443137 + TxOutDatumNone
# 1a0546ce465756200237b7683269eab82446473c26d4aa931349dc8b51d355b4     3        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c5037 + TxOutDatumNone
#
# Lender 30 = addr_test1qp5g75sm5esea8alu07e8c5k63ywns5tq74lvh8ursr48s7r7cz4mu6gh005gdck67p7y9d8s8zsfgjkcdy75mrjh6jqjpx5tl
# TxId "ccc7eaa09e53583833d0c88279f926b3b3de268e8cafad1f98b368bdabb7a070"
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# ccc7eaa09e53583833d0c88279f926b3b3de268e8cafad1f98b368bdabb7a070     0        19483726 lovelace + TxOutDatumNone
# ccc7eaa09e53583833d0c88279f926b3b3de268e8cafad1f98b368bdabb7a070     1        2000000 lovelace + 5067524 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
# ccc7eaa09e53583833d0c88279f926b3b3de268e8cafad1f98b368bdabb7a070     2        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c4431 + TxOutDatumNone
# ccc7eaa09e53583833d0c88279f926b3b3de268e8cafad1f98b368bdabb7a070     3        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.4c503231 + TxOutDatumNone

# %% [markdown]
# ### 8. Close the contract

# %% [markdown]
# The administrator receives back their initial Ada and liquidity tokens.

# %%
marlowe-cli run prepare --notify                                                \
                        --invalid-before $NOW                                   \
                        --invalid-hereafter $((ULTIMATE_DEADLINE - 1 * MINUTE)) \
                        --marlowe-file collective-loan-$k.marlowe               \
                        --out-file     collective-loan-$((1+k)).marlowe
# Out:
# Payment 1
#   Acccount: "A"
#   Payee: Party "A"
#   Ada: 2.000000
# Payment 2
#   Acccount: "A"
#   Payee: Party "A"
#   Ada: 0.000000
#   5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd."Liquidity": 150000000
# Payment 3
#   Acccount: "A"
#   Payee: Party "A"
#   Ada: 0.000000
#   76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf."DjedUSD": 1

# %% [markdown]
# Submit the transactions.

# %%
TX_ADA=$(find_ada $ADMIN_ADDR)
marlowe-cli run execute --marlowe-in-file collective-loan-$k.marlowe          \
                        --tx-in-marlowe "$TX_OLD#1"                           \
                        --tx-in-collateral $TX_ADA                            \
                        --tx-in $TX_ADA                                       \
                        --tx-in "$(find_role_token $ADMIN_ADDR $ADMIN_ROLE)"  \
                        --tx-out "$(make_role_txout $ADMIN_ADDR $ADMIN_ROLE)" \
                        --marlowe-out-file collective-loan-$((k+1)).marlowe   \
                        --change-address $ADMIN_ADDR                          \
                        --required-signer $ADMIN_SKEY                         \
                        --out-file /dev/null                                  \
                        --submit 600
# Out:
# TxId "e42d58869dce889c561fec062c47299be49877a98d404c6f1eea9808ca07f82f"

# %%
TX_ADA=$(find_ada $ADMIN_ADDR)
marlowe-cli run withdraw --marlowe-file collective-loan-$((k+1)).marlowe       \
                         --role-name $ADMIN_ROLE                               \
                         --tx-in-collateral $TX_ADA                            \
                         --tx-in $TX_ADA                                       \
                         --tx-in $(find_role_token $ADMIN_ADDR $ADMIN_ROLE)    \
                         --tx-out "$(make_role_txout $ADMIN_ADDR $ADMIN_ROLE)" \
                         --change-address $ADMIN_ADDR                          \
                         --required-signer $ADMIN_SKEY                         \
                         --out-file /dev/null                                  \
                         --submit 600
# Out:
# TxId "402a9b9ff54e541bbf9d25a64bf333b2c011152fddde8b28e0020e5c0097deaf"

# %% [markdown]
# There is no UTxO at the script address.

# %%
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $SCRIPT_ADDR
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------

# %% [markdown]
# There are no UTxOs at the payout address.

# %%
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $ROLES_ADDR
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------

# %% [markdown]
# Defragment and then view the UTxOs at the administrator's address.

# %%
marlowe-cli util clean --required-signer $ADMIN_SKEY --change-address $ADMIN_ADDR --out-file /dev/null --submit 600
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $ADMIN_ADDR
# Out:
# TxId "51dc6cf65e37defa0369fa00d1388a39d4c985de7b597f3fc8e2c9ef14e82ae3"
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 51dc6cf65e37defa0369fa00d1388a39d4c985de7b597f3fc8e2c9ef14e82ae3     0        18523420359 lovelace + TxOutDatumNone
# 51dc6cf65e37defa0369fa00d1388a39d4c985de7b597f3fc8e2c9ef14e82ae3     1        2000000 lovelace + 150000000 5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd.4c6971756964697479 + TxOutDatumNone
# 51dc6cf65e37defa0369fa00d1388a39d4c985de7b597f3fc8e2c9ef14e82ae3     2        2000000 lovelace + 1 76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf.446a6564555344 + TxOutDatumNone
# 51dc6cf65e37defa0369fa00d1388a39d4c985de7b597f3fc8e2c9ef14e82ae3     3        2000000 lovelace + 1 9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78.41 + TxOutDatumNone

# %% [markdown]
# ## Clean Up

# %% [markdown]
# Use Daedalus to send all of the lender and borrower tokens to the administrator.

# %%
echo $ADMIN_ADDR
false
# Out:
# addr_test1vrssw4edcts00kk6lp7p5n64666m23tpprqaarmdwkaq69gfvqnpz
# : 1

# %% [markdown]
# Burn the Djed.

# %%
marlowe-cli util mint --required-signer $ADMIN_SKEY \
                      --change-address $ADMIN_ADDR  \
                      --expires 1000000011          \
                      --count -$TOTAL_DJED          \
                      --out-file /dev/null          \
                      --submit 600                  \
                      $DJED_NAME
# Out:
# PolicyID "76ea6a9aad89b09448e7af765f5a3e89c574989d67d6371a80e58baf"

# %% [markdown]
# Burn the liquidity tokens.

# %%
marlowe-cli util mint --required-signer $ADMIN_SKEY \
                      --change-address $ADMIN_ADDR  \
                      --expires 1000000012          \
                      --count -$POOL_SIZE           \
                      --out-file /dev/null          \
                      --submit 600                  \
                      $LIQUIDITY_NAME
# Out:
# PolicyID "5f10ff15e04456ec25f1a2d64e5584087e584613411e8e9051b70fbd"

# %% [markdown]
# Burn the role tokens.

# %%
marlowe-cli util mint --required-signer $ADMIN_SKEY \
                      --change-address $ADMIN_ADDR  \
                      --expires 1000000013          \
                      --count -1                    \
                      --out-file /dev/null          \
                      --submit 600                  \
                      $ADMIN_ROLE                   \
                      ${LENDER_DEPOSIT_ROLE[@]}     \
                      ${LENDER_PAYMENT_ROLE[@]}     \
                      ${BORROWER_DEPOSIT_ROLE[@]}   \
                      ${BORROWER_PAYMENT_ROLE[@]}
# Out:
# PolicyID "9cb30bdd840cc8b31806c20eae6ed14614d32f10379547d605064e78"

# %% [markdown]
# Check that all of the burning was successful.

# %%
cardano-cli query utxo --testnet-magic $CARDANO_TESTNET_MAGIC --address $ADMIN_ADDR
# Out:
#                            TxHash                                 TxIx        Amount
# --------------------------------------------------------------------------------------
# 7ce391792e2fd04c2bc53d416f28bdb6bf1bf8af371a0cd76a4309e7672dd50b     0        18547732330 lovelace + TxOutDatumNone
